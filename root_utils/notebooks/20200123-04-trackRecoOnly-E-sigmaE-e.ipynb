# %%
from __future__ import print_function
import numpy as np
import torch 
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline

def geometricPad(grid, pad=1):
  M = grid.shape[2]; # 0:batchsize, 1:channels, 2:width, 3:height
  M_new = pad+M+pad;
  new_shape = (grid.shape[0], grid.shape[1], M_new, M_new)
  grid_new = grid.new_zeros(new_shape);
  grid_new[:,:,pad:M+pad,pad:M+pad] = grid;
  grid_new[:,:,0:pad,pad:(M+pad)] = grid[:,:,:,0:pad].flip(-1).transpose(-1,-2);
  grid_new[:,:,pad:(M+pad),0:pad] = grid[:,:,0:pad,:].flip(-2).transpose(-1,-2);
  grid_new[:,:,(M+pad):(M+pad+pad),(pad):(M+pad)] = grid[:,:,:,(M-pad):].flip(-1).transpose(-1,-2);
  grid_new[:,:,pad:(M+pad),(M+pad):(M+pad+pad)] = grid[:,:,(M-pad):,:].flip(-2).transpose(-1,-2);
  return(grid_new);

class Taylorizer:
    """Perform taylor expansion of tensor using pre-computed expansion weights"""
    def __init__(self, mGridPmt, mGridCoord, vectorStartIndices, pad=1, Lambda=0.5):
        """
        mGridPmt:   numpy array with (Height,Width) only significance is
                    1. value should be unique for each grid site
                    2. if no PMT exists, set to -1
        mGridCoord: numpy array with (Ncoords,Height,Width)
        vectorStartIndices: array with the start indices of xyz vectors in Ncoords, e.g.
                            for [x,y,z,dirx,diry,dirz] pass [0,3] which treats (x,y,z) and (dirx,diry,dirz)
                            as a vector
        pad:        the taylor expansion will be performed on a grid with sides 2*pad+1
        Lambda:     the regularization strength. should be something of order the differences in mGridCoord
        """
        
        self.mGridPmt   = mGridPmt
        self.mGridCoord = mGridCoord
        self.vectorStartIndices = vectorStartIndices
        self.pad = pad
        self.Lambda = Lambda
        self.rotPhi = 0.
        self.AA = self.computeTaylorWeights()
    
    def cuda(self):
        self.AA = self.AA.cuda()
    
    def cpu(self):
        self.AA = self.AA.cpu()
        
    def __call__(self, inputs):
        return self.taylorize(inputs)

    def computeTaylorWeights(self):
        pad = self.pad
        mGridPmt = self.mGridPmt
        mGridCoord = self.mGridCoord

        Ncoords = mGridCoord.shape[0]
        Ntaylor = 1 + Ncoords # + (Ncoords*(Ncoords+1))//2
        self.Ntaylor = Ntaylor

        M = mGridPmt.shape[0]
        mGridI = np.reshape(np.repeat(np.arange(M),M), (M,M))
        mGridJ = mGridI.transpose()

        Nshift = 2*pad+1
        dij = np.reshape(np.repeat(np.arange(-pad,pad+1),Nshift), (Nshift,Nshift));
        dis = dij.flatten()
        djs = dij.transpose().flatten();
        Nsites = dis.size;
        
        self.dis = dis
        self.djs = djs
        self.Nsites = Nsites

        mGridPmtpad = geometricPad(torch.tensor(mGridPmt).unsqueeze(0).unsqueeze(0), pad).squeeze(0).squeeze(0).numpy();
        mGridIpad = geometricPad(torch.tensor(mGridI).unsqueeze(0).unsqueeze(0), pad).squeeze(0).squeeze(0).numpy();
        mGridJpad = geometricPad(torch.tensor(mGridJ).unsqueeze(0).unsqueeze(0), pad).squeeze(0).squeeze(0).numpy();

        mGridCoordPad = geometricPad(torch.tensor(mGridCoord).unsqueeze(0), pad).squeeze(0).numpy();


        mGridAA2 = np.zeros((M,M,Nshift,Nshift,Ntaylor))

        pmtI1 = mGridPmt[:,:]; # index in tank.pmt

        x      = np.zeros((Ncoords,M,M,Nsites));     # coordinates for each direction
        skip   = np.zeros((M,M,Nsites), dtype=bool); # for each direction whether we should skip or not
        processedPmtI2s = np.zeros((M,M,Nsites), dtype=int) - 1;

        for diji in range(Nsites):
            di = dis[diji]
            dj = djs[diji]
            # i2 = mGridIpad[pad+di:pad+M+di,pad+dj:pad+M+dj];
            # j2 = mGridJpad[pad+di:pad+M+di,pad+dj:pad+M+dj];
            pmtI2 = mGridPmtpad[(pad+di):(pad+M+di),(pad+dj):(pad+M+dj)];
            processedPmtI2s[:,:,diji] = pmtI2;

            skip[:,:,diji] = np.logical_or(np.equal(pmtI1,-1), np.equal(pmtI2,-1));
            for prev_diji in range(diji):
                skip[:,:,diji] = np.logical_or(skip[:,:,diji], np.equal(processedPmtI2s[:,:,prev_diji],pmtI2));

            x[:,:,:,diji] = mGridCoordPad[:,(pad+di):(pad+M+di),(pad+dj):(pad+M+dj)] - mGridCoord; # 

        # x: (Ncoords,M,M,Nsites)
        # print('x.shape:', x.shape)
        # X: (Ntaylor,M,M,Nsites)
        Xlist = [np.expand_dims(np.ones(x.shape[1:]),0),x]
        #for i in range(Ncoords):
        #    Xlist.append(np.stack([x[i,:,:,:] for j in range(Ncoords-i)]) * x[i:,:,:,:])
        X = np.concatenate(Xlist)
        # print('X.shape:', X.shape)
        X = np.where(np.expand_dims(skip, 0), 0., X);

        # regularization strength
        Lambda = self.Lambda; # this should be somewhat smaller than typical values of x

        MA = np.zeros((M,M,Nsites,Nsites));
        for k in range(Nsites):
            for j in range(Nsites):
                MA[:,:,k,j] = np.add(np.sum(X[:,:,:,k]*X[:,:,:,j], axis=0), Lambda**2 * (k==j));
            # clear skip entries
            MA[:,:,k,:] = np.where(np.expand_dims(skip[:,:,k],-1), 0., MA[:,:,k,:]);
            MA[:,:,:,j] = np.where(np.expand_dims(skip[:,:,j],-1), 0., MA[:,:,:,j]);
            # set diagonal:
            MA[:,:,k,k] = np.where(skip[:,:,k], 1., MA[:,:,k,k]);

        #print('MA.shape:',MA.shape)
        #print(MA[0,1,:,:])
        #print(np.linalg.inv(MA[0,1,:,:]))
        print("starting inversion... (may take a few seconds)")
        AA = np.einsum('hwsi,thwi->thws', np.linalg.inv(MA), X)
        print("done")
        # print('AA.shape:', AA.shape)
        return torch.tensor(AA, dtype=torch.float)
    
    def taylorize(self, inputs):
        Batches = inputs.shape[0]
        ChIn    = inputs.shape[1]
        Height  = inputs.shape[2]
        Width   = inputs.shape[3]
        tGridAA = self.AA

        inputsPad = geometricPad(inputs, self.pad); # (B,C,W,H)
        tayloredInput = inputs.new_zeros((Batches, self.Ntaylor, ChIn, Height, Width))
        
        # we use new_zeros and set diagonal to 1, because there is no new_eye method
        rotMatrix = inputs.new_zeros(self.Ntaylor, self.Ntaylor)
        for d in range(self.Ntaylor):
            rotMatrix[d,d] = 1.
        
        for startIndex in self.vectorStartIndices:
            startIndex = 1 + startIndex # the 1 is offset due to scalar
            d_x = 0
            d_y = 1
            rotMatrix[startIndex+d_x,startIndex+d_x] =  np.cos(self.rotPhi);
            rotMatrix[startIndex+d_x,startIndex+d_y] =  np.sin(self.rotPhi); # this is an inverse rotation because w is covariant
            rotMatrix[startIndex+d_y,startIndex+d_x] = -np.sin(self.rotPhi);
            rotMatrix[startIndex+d_y,startIndex+d_y] =  np.cos(self.rotPhi);
        
        #print('tGridAA.shape:', tGridAA.shape)
        #print('tayloredInput.shape:', tayloredInput.shape)
        #print('inputsPad.shape:', inputsPad.shape)
        for k in range(self.Nsites):
            # shift grid according to position (without copying the data)
            inputsPadD1 = torch.narrow(inputsPad,   2, self.pad+int(self.dis[k]), Height)
            inputsPadD2 = torch.narrow(inputsPadD1, 3, self.pad+int(self.djs[k]), Width )
            # fill
            # d,e: directional index (Ntaylor)
            # i,j: grid indices
            # b: event in batch
            # c: channel
            out = torch.add(tayloredInput, torch.einsum('dij,bcij->bdcij', tGridAA[:,:,:,k], inputsPadD2))
            tayloredInput = out
        
        if self.rotPhi != 0.:
            org = tayloredInput
            tayloredInput = torch.einsum('bdcij,ed->becij', org, rotMatrix).contiguous()
            #tayloredInput = out
        
        #print('tayloredInput.shape', tayloredInput.shape, 'to', (Batches, self.Ntaylor*ChIn, Height, Width))
        return tayloredInput.view(Batches, self.Ntaylor*ChIn, Height, Width)
    
    def pool2d(self, kernel_size, pad=-1, Lambda=-1.):
        """
        Return new Taylorizer that can be used for the result of a 2d pool operation with given kernel size.
        kernel_size: e.g. for 2x2 max-pooling use (2,2)
        pad:    if unset (-1)  use same as current
        Lambda: if unset (-1.) use same as current
        """
        mGridPmt1   = torch.nn.functional.max_pool2d(torch.tensor(self.mGridPmt  ).to(torch.float).unsqueeze(0), kernel_size).squeeze(0).to(torch.long).numpy()
        mGridFilled1 = torch.nn.functional.avg_pool2d(torch.tensor((self.mGridPmt >= 0).astype(float)).unsqueeze(0), kernel_size).squeeze(0).numpy()
        
        mGridCoord1 = torch.nn.functional.avg_pool2d(torch.tensor(self.mGridCoord), kernel_size).numpy()
        mGridCoord1 /= mGridFilled1 # correct average for missing positions
        
        if (pad < 0):
            pad = self.pad
        if (Lambda < 0.):
            Lambda = self.Lambda
        
        return Taylorizer(mGridPmt1, mGridCoord1, self.vectorStartIndices, pad=pad, Lambda=Lambda)
    
def imshowRdBu(ax,img):
    minmax = max(torch.max(img),-torch.min(img))
    return ax.imshow(-img,cmap='RdBu',vmin=-minmax,vmax=minmax)

from torch.utils.data import Dataset, DataLoader

class H5Dataset(Dataset):

    def __init__(self, files, transform=None, flavour=None, limit_num_files=0, start_fraction=0., use_fraction=1.0):
        """                                                                                                                                             
        Args: data_dirs ... a list of data directories to find files (up to 10 files read from each dir)                                                
              transform ... a function applied to pre-process data                                                                                      
              flavour ..... a string that is required to be present in the filename                                                                     
              limit_num_files ... an integer limiting number of files to be taken per data directory                                                    
              start_fraction ... a floating point fraction (0.0=>1.0) to specify which entry to start reading (per file)                                
              use_fraction ..... a floating point fraction (0.0=>1.0) to specify how much fraction of a file to be read out (per file)                  
        """
        self._transform = transform
        self._files = []

        # Check input fractions makes sense                                                                                                             
        assert start_fraction >= 0. and start_fraction < 1.
        assert use_fraction > 0. and use_fraction <= 1.
        assert (start_fraction + use_fraction) <= 1.

        # Load files (up to 10) from each directory in data_dirs list                                                                                   
        # for d in data_dirs:
        #     file_list = [ os.path.join(d,f) for f in os.listdir(d) if flavour is None or flavour in f ]
        #     if limit_num_files: file_list = file_list[0:limit_num_files]
        #     self._files += file_list
        self._files = files

        self._file_handles = [None] * len(self._files)
        self._event_to_file_index  = []
        self._event_to_entry_index = []
        import h5py
        for file_index, file_name in enumerate(self._files):
            f = h5py.File(file_name,mode='r')
            data_size = f['event_data'].shape[0]
            start_entry = int(start_fraction * data_size)
            num_entries = int(use_fraction * data_size)
            self._event_to_file_index += [file_index] * num_entries
            self._event_to_entry_index += range(start_entry, start_entry+num_entries)
            f.close()

    def __len__(self):
        return len(self._event_to_file_index)

    def __getitem__(self,idx):
        file_index = self._event_to_file_index[idx]
        entry_index = self._event_to_entry_index[idx]
        if self._file_handles[file_index] is None:
            import h5py
            self._file_handles[file_index] = h5py.File(self._files[file_index],mode='r')
        fh = self._file_handles[file_index]
        label = fh['labels'][entry_index]
        #labelTranslation = [-1,0,1,-1,2] # make sure that labels 1,2,4 get values 0,1,2
        if label == 1: # electron
            label = 0
        elif label == 2: # muon
            label = 1
        elif label == 4: # pip
            label = 2
        else:
            print('Unknown label', label, 'for entry_index', entry_index, 'treating as label=0')
            label = 0
        
        # try:
        #     label = labelTranslation[label]
        # except IndexError:
        #     print('IndexError at entry', entry_index, 'label in file was', fh['labels'][entry_index], 'translations are', labelTranslation)
        #     raise
        
        event_data = fh['event_data'][entry_index]
        return event_data[:,:,0:2],label,idx

def HKCollate(batch):
    data  = np.stack([sample[0] for sample in batch])
    label = [sample[1] for sample in batch]
    idx   = [sample[2] for sample in batch]
    rndmRot = np.random.uniform(0., 2*np.pi)
    return data,label,idx,rndmRot

class H5DatasetWithTrack(Dataset):

    def __init__(self, files, transform=None, flavour=None, limit_num_files=0, start_fraction=0., use_fraction=1.0):
        """                                                                                                                                             
        Args: data_dirs ... a list of data directories to find files (up to 10 files read from each dir)                                                
              transform ... a function applied to pre-process data                                                                                      
              flavour ..... a string that is required to be present in the filename                                                                     
              limit_num_files ... an integer limiting number of files to be taken per data directory                                                    
              start_fraction ... a floating point fraction (0.0=>1.0) to specify which entry to start reading (per file)                                
              use_fraction ..... a floating point fraction (0.0=>1.0) to specify how much fraction of a file to be read out (per file)                  
        """
        self._transform = transform
        self._files = []

        # Check input fractions makes sense                                                                                                             
        assert start_fraction >= 0. and start_fraction < 1.
        assert use_fraction > 0. and use_fraction <= 1.
        assert (start_fraction + use_fraction) <= 1.

        # Load files (up to 10) from each directory in data_dirs list                                                                                   
        # for d in data_dirs:
        #     file_list = [ os.path.join(d,f) for f in os.listdir(d) if flavour is None or flavour in f ]
        #     if limit_num_files: file_list = file_list[0:limit_num_files]
        #     self._files += file_list
        self._files = files

        self._file_handles = [None] * len(self._files)
        self._event_to_file_index  = []
        self._event_to_entry_index = []
        import h5py
        for file_index, file_name in enumerate(self._files):
            f = h5py.File(file_name,mode='r')
            data_size = f['event_data'].shape[0]
            start_entry = int(start_fraction * data_size)
            num_entries = int(use_fraction * data_size)
            self._event_to_file_index += [file_index] * num_entries
            self._event_to_entry_index += range(start_entry, start_entry+num_entries)
            f.close()

    def __len__(self):
        return len(self._event_to_file_index)

    def __getitem__(self,idx):
        file_index = self._event_to_file_index[idx]
        entry_index = self._event_to_entry_index[idx]
        if self._file_handles[file_index] is None:
            import h5py
            self._file_handles[file_index] = h5py.File(self._files[file_index],mode='r')
        fh = self._file_handles[file_index]
        label = fh['labels'][entry_index]
        #labelTranslation = [-1,0,1,-1,2] # make sure that labels 1,2,4 get values 0,1,2
        if label == 1: # electron
            label = 0
        elif label == 2: # muon
            label = 1
        elif label == 4: # pip
            label = 2
        else:
            print('Unknown label', label, 'for entry_index', entry_index, 'treating as label=0')
            label = 0
        
        # try:
        #     label = labelTranslation[label]
        # except IndexError:
        #     print('IndexError at entry', entry_index, 'label in file was', fh['labels'][entry_index], 'translations are', labelTranslation)
        #     raise
        
        keys = ['event_data','directions','energies','positions']
        out = {
            "label":      label,
            "idx":        idx
        }
        for key in iter(keys):
            out[key] = fh[key][entry_index]
        
        return out

def HKCollateWithTrack(batch):
    stack = {}
    for key in iter(batch[0].keys()):
        if key == "event_data" or key == "directions" or key == "energies" or key == "positions":
            stack[key] = np.stack([sample[key] for sample in batch])
        else:
            stack[key] = [sample[key] for sample in batch]
    
    stack["rndmRot"] = np.random.uniform(0., 2*np.pi)
    return stack
# e.g. positions will have shape (B,2,3) with B=batch-size, 2=(the two particles), 3=(vector coordinates)

class GeomBNConv2d(torch.nn.Module):
    def __init__(self,Cin,Cout,pad):
        super(GeomBNConv2d, self).__init__()
        self.Cin = Cin
        self.Cout = Cout
        self.pad = pad
        self.batchNorm2d = torch.nn.BatchNorm2d(Cin)
        self.conv2d = torch.nn.Conv2d(Cin,Cout,2*self.pad+1)
 
    def forward(self, x):
        x = self.batchNorm2d(x)
        inputsPad = geometricPad(x, self.pad); # (B,C,W,H)
        return self.conv2d(inputsPad)

class TaylorBNConv2d(torch.nn.Module):
    def __init__(self,Cin,Cout,taylor):
        super(TaylorBNConv2d, self).__init__()
        self.Cin = Cin
        self.Cout = Cout
        self.taylor = taylor
        self.batchNorm2d = torch.nn.BatchNorm2d(Cin*taylor.Ntaylor)
        self.conv2d = torch.nn.Conv2d(Cin*taylor.Ntaylor,Cout,1)
 
    def forward(self, x):
        x = self.taylor(x)
        x = self.batchNorm2d(x)
        x = self.conv2d(x)
        return x
    
    # the default implementation of cpu() and cuda() only passes this along to nn.Module instances
    # since self.AA is a tensor, we need to take care of it ourselves
    
    def cpu(self):
        super(TaylorBNConv2d, self).cpu()
        self.taylor.cpu()
        return self
    
    def cuda(self):
        super(TaylorBNConv2d, self).cuda()
        self.taylor.cuda()
        return self


class TaylorCNN(torch.nn.Module):
    
    def __init__(self, num_class, taylor):
        super(TaylorCNN, self).__init__()
        
        # prepare taylorizers for maxpool operations
        self.taylor0 = taylor
        self.taylor1 = self.taylor0.pool2d((2,2))
        self.taylor2 = self.taylor1.pool2d((2,2))
        self.taylor3 = self.taylor2.pool2d((2,2))
        #taylor4 = taylor3.pool2d((2,2))
        
        # feature extractor CNN
        self._feature = torch.nn.Sequential(
            # taylor conv
            TaylorBNConv2d( 1,16,self.taylor0), torch.nn.ReLU(),
            TaylorBNConv2d(16,32,self.taylor0), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d(32,32,self.taylor1), torch.nn.ReLU(),
            TaylorBNConv2d(32,32,self.taylor1), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d(32,64,self.taylor2), torch.nn.ReLU(),
            TaylorBNConv2d(64,64,self.taylor2), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d( 64,128,self.taylor3), torch.nn.ReLU(),
            TaylorBNConv2d(128,128,self.taylor3), torch.nn.ReLU()
        )
        self._classifier = torch.nn.Sequential(
            torch.nn.Linear(128+1,32), torch.nn.ReLU(), # the +1 is because of the chrgsum
            torch.nn.Linear(32,num_class)
        )

    def forward(self, x):
        totalCharge = torch.sum(x[:,0,:,:], (1,2)) # resulting shape will be [B]
        net = self._feature(x)
        net = torch.nn.AvgPool2d(net.size()[2:])(net)
        return self._classifier(torch.cat([net.view(-1,128), totalCharge.view(-1,1)], dim=1))
    
    def rot(self, phi):
        self.taylor0.rotPhi = phi
        self.taylor1.rotPhi = phi
        self.taylor2.rotPhi = phi
        self.taylor3.rotPhi = phi
    
    # I'm not sure why I need to implement cpu/cuda myself, train works somehow
    
    def cpu(self):
        super(TaylorCNN, self).cpu()
        for module in self._feature:
            module.cpu()
        for module in self._classifier:
            module.cpu()
        return self
    
    def cuda(self):
        super(TaylorCNN, self).cuda()
        for module in self._feature:
            module.cuda()
        for module in self._classifier:
            module.cuda()
        return self

# %%
f = h5py.File('/home/lukasb/projects/rpp-tanaka-ab/lukasb/watchmal/20190808-uniisoflat/1Rmu-blacksheet/wc-0-bch1.h5','r')
event_data = f['event_data'][:]

# %%
mGridPmt = f['mGridPmt'][()]
mGridCoord = np.stack([
    f['mGridX'][()]/20.,
    f['mGridY'][()]/20.,
    f['mGridZ'][()]/20.,
    f['mGridDirX'][()],
    f['mGridDirY'][()],
    f['mGridDirZ'][()]
])
mGridVectorStartIndices = [0,3]

taylor0 = Taylorizer(mGridPmt, mGridCoord, mGridVectorStartIndices, pad=1, Lambda=1.)
# Out:
# starting inversion... (may take a few seconds)
# done

# %%
# filters = torch.randn(Cout,Cin,Hflt,Wflt);
inputs = torch.tensor(event_data[(0,5),:,:,0]).unsqueeze(1);
tayloredInput = taylor0(inputs)

for ev in range(tayloredInput.shape[0]):
    print(ev)
    taylorTitles = ['1','x','y','z','dir_x','dir_y','dir_z']
    fig, axes = plt.subplots(1, taylor0.Ntaylor, figsize=(16,8),facecolor='w')
    for itaylor in range(taylor0.Ntaylor):
        imshowRdBu(axes[itaylor], tayloredInput[ev,itaylor,:,:]); axes[itaylor].set_title(taylorTitles[itaylor])
    plt.show()
# Out:
# 0
# 1

# %%
mcdir = '/home/lukasb/scratch/20190808-uniisoflat'
wallmat = 'blacksheet'
pnames = ('e')
files = ['%s/1R%s-%s/wc-0-bch%d.h5' % (mcdir,pname,wallmat,bch+1) for bch in range(100) for pname in pnames]

train_ds = H5DatasetWithTrack(files,start_fraction=0.0,use_fraction=0.9);
test_ds  = H5DatasetWithTrack(files,start_fraction=0.9,use_fraction=0.1);

# for training
train_loader=DataLoader(train_ds,batch_size= 64,shuffle=True,num_workers=4,collate_fn=HKCollateWithTrack)
# for validation
test_loader =DataLoader( test_ds,batch_size=200,shuffle=True,num_workers=2,collate_fn=HKCollateWithTrack)

# %%
class WeightedLoss(torch.nn.Module):
    # losses should be a list of 2-tuples (Npred,Loss)
    # where Npred is the number of prediction params to use for this loss,
    # and Loss is the loss function to evaluate.
    # The loss functions are applied to the input value in the given order.
    # 
    # the initScale can be a list of typical scales for the losses, which is used to initialize logVar=log(initScales)
    # 
    # from A. Kendall et al., “Multi-Task Learning Using Uncertainty to Weigh Losses for Scene Geometry and Semantics” (2018)
    # the idea is to add weight parameters to the loss function as 
    # totalLoss = sum_i [L_i/V_i + log V_i]
    # such that
    # 0 = d(totalLoss)/dV_i
    #   = -1/V_i^2 [L_i - V_i]
    # so by optimizing V_i, it becomes equal to the typical scale of L_i
    def __init__(self,losses,initScale=None):
        super(WeightedLoss, self).__init__()
        
        self.predPartitions = []
        self.losses = []
        predCumsum = 0
        for Npred,loss in losses:
            self.predPartitions.append((predCumsum,Npred)) # start and length
            predCumsum = predCumsum + Npred
            self.losses.append(loss)
        
        Nlosses = len(losses)
        if initScale is None:
            initScale = np.ones(Nlosses)
        self.logVar = torch.nn.Parameter(torch.log(torch.tensor(initScale, dtype=torch.float)))
        self.logVar.requires_grad = True
 
    def forward(self, pred, true):
        # pred is a 1d tensor with length sum(Npred)
        # true is a normal python list of the true values to pass to each loss function (probably each a tensor)
        oneOverVar = torch.exp(-self.logVar)
        totalLoss = self.logVar.sum()
        for i,loss in enumerate(self.losses):
            thisPred = pred.narrow(1,self.predPartitions[i][0],self.predPartitions[i][1])
            thisTrue = true[i]
            totalLoss = totalLoss + oneOverVar[i]*loss(thisPred,thisTrue)
        
        return totalLoss
    
    # the default implementation of cpu() and cuda() only passes this along to nn.Module instances
    # since self.logSigma is a tensor, we need to take care of it ourselves
    
    def cpu(self):
        super(WeightedLoss, self).cpu()
        self.logVar.cpu()
        return self
    
    def cuda(self):
        super(WeightedLoss, self).cuda()
        self.logVar.cuda()
        return self

# %%
loss = WeightedLoss([(3,torch.nn.CrossEntropyLoss()), (1,torch.nn.SmoothL1Loss())])
loss(torch.zeros([1,4]), [torch.tensor([1]),torch.tensor([[0.]])])
print(list(loss.parameters()))
# Out:
# [Parameter containing:
# tensor([0., 0.], requires_grad=True)]

# %%
def prepareTruth(blob):
    trueLabel = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()
    trueLabel.requires_grad = False
    
    # we will predict sqrt(E) since this gives a more typical error scale
    # with sigma(E)~sqrt(E) we have
    # sigma(sqrt(E)) ~ d[sqrt(E)]/dE sigma(E)
    #                = 0.5 * sqrt(E)/sqrt(E)
    #                = 0.5
    trueSqrtEnergy = torch.as_tensor(np.sqrt(blob.energies[:,0:1])).type(torch.FloatTensor).cuda()
    trueSqrtEnergy.requires_grad = False
    
    return trueSqrtEnergy

def computeAccuracy(blob,prediction):
    truth = prepareTruth(blob)
    #trueLabel = truth[0]
    trueEnergy = torch.pow(truth,2)
    
    Nclasses = 0
    #predLabel = prediction[:,0:Nclasses]
    #softmax    = blob.softmax(predLabel).cpu().detach().numpy()
    #whichLabel = torch.argmax(predLabel,dim=-1)
    #accuracy   = (whichLabel == trueLabel).sum().item() / float(whichLabel.nelement())
    #whichLabel = whichLabel.cpu().detach().numpy()
    softmax = 0.
    accuracy = 0.
    whichLabel = 0.
    
    predEnergy = torch.pow(prediction[:,0:1],2)
    # only care about the first energy for now
    # we are squaring the energy since "trueEnergy" is sqrt(E)
    energyResolution = blob.mse(predEnergy/trueEnergy, trueEnergy*0. + 1.)
    energyResolution = energyResolution.cpu().detach().numpy()
    energyResolution = np.sqrt(energyResolution.mean()).item()
    
    out = {
        "accuracy": accuracy,                 # double
        "energyResolution": energyResolution, # double
        "softmax": softmax,                   # np.array (batch,labels)
        "prediction": whichLabel,             # np.array (batch)
        "predEnergy": predEnergy.cpu().detach().numpy() # np.array (batch)
    }
    return out

def forward(blob,train=True):
    """
       Args: blob should have attributes, net, criterion, softmax, data, label
       Returns: a dictionary of predicted labels, softmax, loss, and accuracy
    """
    with torch.set_grad_enabled(train):
        # Prediction
        data = torch.as_tensor(blob.data).cuda()
        data = data.permute(0,3,1,2)
        prediction = blob.net(data[:,0:1,:,:])
        # prediction.shape = (batchSize,nClasses) 
        
        # Training
        loss,acc=-1,-1
        if blob.label is not None:
            truth = prepareTruth(blob)
            #print(prediction.size(), [t.size() for t in truth])
            #loss = blob.criterion(prediction, truth)
            
            trueE = truth[:,0]
            predE = prediction[:,0]
            neglogsigmaESqr = torch.clamp(prediction[:,1], -5., 5.)
            loss = torch.sum(torch.pow(predE - trueE,2)/torch.pow(trueE,2)*torch.exp(neglogsigmaESqr) - neglogsigmaESqr)
        blob.loss = loss
        #print(loss)
        
        out = computeAccuracy(blob, prediction)
        out['loss'] = loss.cpu().detach().item()
        
        return out

def backward(blob):
    blob.optimizer.zero_grad()  # Reset gradients accumulation
    blob.loss.backward()
    blob.optimizer.step()

def save_state(blob):
    # Output file name
    filename = '%s-%d.ckpt' % (blob.prefix, blob.iteration)
    # Save parameters
    # 0+1) iteration counter + optimizer state => in case we want to "continue training" later
    # 2) network weight
    torch.save({
        'global_epoch': blob.epoch,
        'global_step': blob.iteration,
        'optimizer': blob.optimizer.state_dict(),
        'state_dict': blob.net.state_dict()
        }, filename)
    return filename

def restore_state(blob, iteration):
    # Open a file in read-binary mode
    weight_file = '%s-%d.ckpt' % (blob.prefix, iteration)
    with open(weight_file, 'rb') as f:
        # torch interprets the file, then we can access using string keys
        checkpoint = torch.load(f)
        # load network weights
        blob.net.load_state_dict(checkpoint['state_dict'], strict=False)
        # if optimizer is provided, load the state of the optimizer
        if blob.optimizer is not None:
            blob.optimizer.load_state_dict(checkpoint['optimizer'])
        # load iteration count
        blob.epoch     = checkpoint['global_epoch']
        blob.iteration = checkpoint['global_step']

# weight_file = save_state(blob, '20190819-02-DeepTaylor-01-BatchNorm')
# print('Saved to', weight_file)


# # Recreate the network (i.e. initialize)
# blob.net=LeNet().cuda()
# # Get one batch of data to test
# blob.data, blob.label = next(iter(train_loader))
# # Run forward function
# res = forward(blob,True)
# # Report
# print('Accuracy:',res['accuracy'])



# # Restore the state
# restore_state(weight_file,blob)
# # Run the forward function
# res = forward(blob,True)
# # Report
# print('Accuracy',res['accuracy'])

# %%
import math

class BLOB:
    pass
blob=BLOB()
Nreco = 2
blob.net       = TaylorCNN(Nreco, taylor0).cuda() # construct CNN for 1 energy, use GPU
# blob.criterion =  (custom function)
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.mse       = torch.nn.MSELoss()      # not for training, but for accuracy estimation
blob.prefix    = '20200123-04-trackRecoOnly-E-sigmaE-e-01-chrgsum'
blob.epoch     = 0.
blob.iteration = 0
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis
blob.energies  = None # energies for training/analysis
# Out:
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done

# %%
import time
from utils.utils import progress_bar, CSVData

blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)

# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=1.0
# Set the network to training mode
blob.net.train()

# Start training
while int(blob.epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(blob.epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data  = data['event_data']
        blob.label = data['label']
        blob.energies = data['energies']
        blob.net.rot(data['rndmRot'])
        # here we would also need to rotate the truth information (i.e. any vector data in label)
        
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        blob.epoch += 1./len(train_loader)
        blob.iteration += 1
        
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%3 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%50 == 0:
            with torch.no_grad():
                blob.net.eval()
                test_data = next(iter(test_loader))
                blob.data  = test_data['event_data']
                blob.label = test_data['label']
                blob.energies = test_data['energies']
                blob.net.rot(test_data['rndmRot'])
                res = forward(blob,False)
                blob.test_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
                blob.test_log.write()
            blob.net.train()
        # even more rarely, save state
        if (i+1)%400 == 0:
            with torch.no_grad():
                blob.net.eval()
                save_state(blob)
            blob.net.train()
        if blob.epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
    #print(message)
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.test_log.close()
blob.train_log.close()
# Out:
# Epoch 0 Starting @ 2020-01-30 08:17:05
#         <progress
#             value='704'
#             max='704',
#             style='width: 30%'
#         >
#             704
#         </progress> 100% ... Iteration 704 ... Epoch 1.00 ... Loss 38.567 ... Accuracy 0.000 ... Eres 13.205

# %%
# import time
# from utils.utils import progress_bar, CSVData
# 
# blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)
# 
# restore_state(blob, 4316)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)
ax1.set_yscale('log')

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.energyResolution, linewidth=2, label='Train Eres', color='g', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.energyResolution, marker='o', markersize=12, linestyle='', label='Test Eres', color='green')

ax2.set_ylabel('Energy resolution', fontsize=24, fontweight='bold',color='g')
ax2.tick_params('y',colors='g',labelsize=18)
ax2.set_ylim(0.,3.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %%
with torch.no_grad():
    Nrows = 5
    iter_test_loader = iter(test_loader)
    for r in range(Nrows):
        Nplot = 5
        fig, axes = plt.subplots(1, Nplot, figsize=(16,3),facecolor='w')

        test_data = next(iter_test_loader)
        
        blob.net.eval()
        # Data and label
        blob.data  = test_data['event_data']
        blob.label = test_data['label']
        blob.energies = test_data['energies']
        # limit #plots
        blob.data  = blob.data[0:Nplot,:,:,:]
        blob.label = blob.label[0:Nplot]
        blob.energies = blob.energies[0:Nplot,:]

        res = forward(blob,False)

        for ev in range(Nplot):
            im = axes[ev].imshow(blob.data[ev,:,:,0])
            #labelNames = ['e','μ','π+']
            #correct = (blob.label[ev] == res['prediction'][ev])
            axes[ev].set_title(
                'pred: %.0f MeV\ntrue: %.0f MeV' %
                (
                    res['predEnergy'][ev],
                    blob.energies[ev,0]
                )
            )
            cbar = fig.colorbar(im, ax=axes[ev])
        plt.show()

        del test_data
        del blob.data
        del blob.label
    
    del iter_test_loader

# %%
with torch.no_grad():
    Nrows = 5
    iter_test_loader = iter(test_loader)
    
    trueE = []
    predE = []
    trueLabel = []
    for r in range(Nrows):
        test_data = next(iter_test_loader)
        
        blob.net.eval()
        # Data and label
        blob.data  = test_data['event_data']
        blob.label = test_data['label']
        blob.energies = test_data['energies']

        res = forward(blob,False)
        
        trueE.extend(blob.energies[:,0])
        predE.extend(res['predEnergy'])
        
        trueLabel.extend(blob.label)

    del iter_test_loader

plt.scatter(trueE, predE, c=trueLabel, alpha=0.5)
plt.xlabel('True energy [MeV]')
plt.ylabel('Reconstructed energy [MeV]')
plt.show()

# %%
predE
# Out:
# [array([2932.209], dtype=float32),
#  array([13597.506], dtype=float32),
#  array([13.802946], dtype=float32),
#  array([14539.269], dtype=float32),
#  array([5431.9507], dtype=float32),
#  array([9669.562], dtype=float32),
#  array([3034.1418], dtype=float32),
#  array([2687.4382], dtype=float32),
#  array([714.45905], dtype=float32),
#  array([7648.822], dtype=float32),
#  array([993.16235], dtype=float32),
#  array([8923.925], dtype=float32),
#  array([4803.5996], dtype=float32),
#  array([152.92334], dtype=float32),
#  array([1603.9884], dtype=float32),
#  array([80.26542], dtype=float32),
#  array([14186.994], dtype=float32),
#  array([16127.75], dtype=float32),
#  array([295.14645], dtype=float32),
#  array([281.5217], dtype=float32),
#  array([24589.266], dtype=float32),
#  array([20724.936], dtype=float32),
#  array([1515.1971], dtype=float32),
#  array([18143.365], dtype=float32),
#  array([14090.628], dtype=float32),
#  array([8689.031], dtype=float32),
#  array([8240.126], dtype=float32),
#  array([17716.082], dtype=float32),
#  array([644.7061], dtype=float32),
#  array([5373.378], dtype=float32),
#  array([9500.311], dtype=float32),
#  array([1163.4187], dtype=float32),
#  array([16645.17], dtype=float32),
#  array([1300.4412], dtype=float32),
#  array([2094.1565], dtype=float32),
#  array([42.01284], dtype=float32),
#  array([5133.737], dtype=float32),
#  array([1163.2324], dtype=float32),
#  array([2681.4824], dtype=float32),
#  array([20962.354], dtype=float32),
#  array([26989.], dtype=float32),
#  array([2485.222], dtype=float32),
#  array([62.246735], dtype=float32),
#  array([459.9447], dtype=float32),
#  array([6932.6064], dtype=float32),
#  array([7438.011], dtype=float32),
#  array([831.04443], dtype=float32),
#  array([992.8788], dtype=float32),
#  array([517.5178], dtype=float32),
#  array([36.34842], dtype=float32),
#  array([21975.402], dtype=float32),
#  array([18.41743], dtype=float32),
#  array([14259.012], dtype=float32),
#  array([18581.852], dtype=float32),
#  array([225.60483], dtype=float32),
#  array([11906.632], dtype=float32),
#  array([3642.2043], dtype=float32),
#  array([2689.824], dtype=float32),
#  array([3610.8843], dtype=float32),
#  array([9993.252], dtype=float32),
#  array([10131.951], dtype=float32),
#  array([24878.25], dtype=float32),
#  array([837.4903], dtype=float32),
#  array([14372.873], dtype=float32),
#  array([15931.851], dtype=float32),
#  array([2713.6619], dtype=float32),
#  array([1936.9337], dtype=float32),
#  array([2846.7898], dtype=float32),
#  array([13220.569], dtype=float32),
#  array([3416.8977], dtype=float32),
#  array([2105.113], dtype=float32),
#  array([7086.8877], dtype=float32),
#  array([20612.768], dtype=float32),
#  array([13524.756], dtype=float32),
#  array([14214.837], dtype=float32),
#  array([2672.1099], dtype=float32),
#  array([12572.89], dtype=float32),
#  array([605.8279], dtype=float32),
#  array([7771.277], dtype=float32),
#  array([5396.051], dtype=float32),
#  array([14615.401], dtype=float32),
#  array([1822.3605], dtype=float32),
#  array([7811.422], dtype=float32),
#  array([107.22385], dtype=float32),
#  array([35.865395], dtype=float32),
#  array([2037.2625], dtype=float32),
#  array([120.704895], dtype=float32),
#  array([67.8692], dtype=float32),
#  array([9403.526], dtype=float32),
#  array([2383.5916], dtype=float32),
#  array([19868.979], dtype=float32),
#  array([7960.7983], dtype=float32),
#  array([314.82983], dtype=float32),
#  array([20430.51], dtype=float32),
#  array([73.93356], dtype=float32),
#  array([18007.824], dtype=float32),
#  array([89.579765], dtype=float32),
#  array([3279.5344], dtype=float32),
#  array([11708.147], dtype=float32),
#  array([16879.12], dtype=float32),
#  array([188.63023], dtype=float32),
#  array([502.65924], dtype=float32),
#  array([1386.333], dtype=float32),
#  array([3922.613], dtype=float32),
#  array([3815.7168], dtype=float32),
#  array([15827.935], dtype=float32),
#  array([14743.517], dtype=float32),
#  array([59.105385], dtype=float32),
#  array([4427.5024], dtype=float32),
#  array([93.89735], dtype=float32),
#  array([16016.948], dtype=float32),
#  array([1657.833], dtype=float32),
#  array([9131.621], dtype=float32),
#  array([12829.225], dtype=float32),
#  array([507.86688], dtype=float32),
#  array([15039.847], dtype=float32),
#  array([11350.549], dtype=float32),
#  array([921.03546], dtype=float32),
#  array([1681.5728], dtype=float32),
#  array([13845.62], dtype=float32),
#  array([7980.055], dtype=float32),
#  array([6243.3594], dtype=float32),
#  array([13547.148], dtype=float32),
#  array([13678.024], dtype=float32),
#  array([1293.3013], dtype=float32),
#  array([413.5841], dtype=float32),
#  array([133.44391], dtype=float32),
#  array([4358.372], dtype=float32),
#  array([10253.957], dtype=float32),
#  array([994.433], dtype=float32),
#  array([19010.941], dtype=float32),
#  array([12146.829], dtype=float32),
#  array([15364.188], dtype=float32),
#  array([35.561523], dtype=float32),
#  array([3579.174], dtype=float32),
#  array([8972.091], dtype=float32),
#  array([1545.03], dtype=float32),
#  array([11667.1], dtype=float32),
#  array([10849.533], dtype=float32),
#  array([15328.678], dtype=float32),
#  array([6278.831], dtype=float32),
#  array([4767.6743], dtype=float32),
#  array([1623.9624], dtype=float32),
#  array([4676.1694], dtype=float32),
#  array([464.58942], dtype=float32),
#  array([94.16457], dtype=float32),
#  array([19921.508], dtype=float32),
#  array([3622.5679], dtype=float32),
#  array([4931.3125], dtype=float32),
#  array([1790.1594], dtype=float32),
#  array([1838.7573], dtype=float32),
#  array([15422.573], dtype=float32),
#  array([10952.624], dtype=float32),
#  array([13791.963], dtype=float32),
#  array([350.92242], dtype=float32),
#  array([214.65787], dtype=float32),
#  array([9268.168], dtype=float32),
#  array([2064.3657], dtype=float32),
#  array([11921.835], dtype=float32),
#  array([18364.787], dtype=float32),
#  array([18285.414], dtype=float32),
#  array([5939.393], dtype=float32),
#  array([15517.563], dtype=float32),
#  array([3795.6973], dtype=float32),
#  array([6597.7803], dtype=float32),
#  array([11835.56], dtype=float32),
#  array([4197.8955], dtype=float32),
#  array([18371.297], dtype=float32),
#  array([5436.4927], dtype=float32),
#  array([8206.981], dtype=float32),
#  array([2473.8643], dtype=float32),
#  array([6279.4585], dtype=float32),
#  array([11654.738], dtype=float32),
#  array([173.34224], dtype=float32),
#  array([3054.9358], dtype=float32),
#  array([441.06265], dtype=float32),
#  array([6947.9536], dtype=float32),
#  array([4255.3457], dtype=float32),
#  array([3556.015], dtype=float32),
#  array([4355.443], dtype=float32),
#  array([18509.53], dtype=float32),
#  array([7640.626], dtype=float32),
#  array([6722.6177], dtype=float32),
#  array([12326.846], dtype=float32),
#  array([4498.863], dtype=float32),
#  array([14857.762], dtype=float32),
#  array([1628.526], dtype=float32),
#  array([777.7723], dtype=float32),
#  array([664.66046], dtype=float32),
#  array([408.8941], dtype=float32),
#  array([5621.24], dtype=float32),
#  array([14695.39], dtype=float32),
#  array([14945.8], dtype=float32),
#  array([2435.9111], dtype=float32),
#  array([8866.341], dtype=float32),
#  array([716.91174], dtype=float32),
#  array([1338.6483], dtype=float32),
#  array([16485.094], dtype=float32),
#  array([9954.637], dtype=float32),
#  array([13695.848], dtype=float32),
#  array([1774.9943], dtype=float32),
#  array([1052.6738], dtype=float32),
#  array([14444.905], dtype=float32),
#  array([4422.455], dtype=float32),
#  array([15971.865], dtype=float32),
#  array([3106.3855], dtype=float32),
#  array([385.40335], dtype=float32),
#  array([12674.193], dtype=float32),
#  array([4256.311], dtype=float32),
#  array([778.0377], dtype=float32),
#  array([684.1255], dtype=float32),
#  array([2064.4197], dtype=float32),
#  array([1794.2986], dtype=float32),
#  array([7665.734], dtype=float32),
#  array([4723.118], dtype=float32),
#  array([14534.582], dtype=float32),
#  array([3030.773], dtype=float32),
#  array([3031.715], dtype=float32),
#  array([9902.035], dtype=float32),
#  array([5740.351], dtype=float32),
#  array([2125.9395], dtype=float32),
#  array([712.14355], dtype=float32),
#  array([4849.4062], dtype=float32),
#  array([14709.828], dtype=float32),
#  array([2288.482], dtype=float32),
#  array([71.99802], dtype=float32),
#  array([7203.3164], dtype=float32),
#  array([874.8058], dtype=float32),
#  array([4339.1177], dtype=float32),
#  array([189.33159], dtype=float32),
#  array([12323.154], dtype=float32),
#  array([16354.702], dtype=float32),
#  array([2762.5894], dtype=float32),
#  array([22363.322], dtype=float32),
#  array([723.58636], dtype=float32),
#  array([15442.877], dtype=float32),
#  array([5772.6445], dtype=float32),
#  array([6876.836], dtype=float32),
#  array([355.3409], dtype=float32),
#  array([14010.558], dtype=float32),
#  array([9374.628], dtype=float32),
#  array([12802.1045], dtype=float32),
#  array([24388.615], dtype=float32),
#  array([9495.739], dtype=float32),
#  array([4977.1426], dtype=float32),
#  array([4132.0273], dtype=float32),
#  array([8637.287], dtype=float32),
#  array([4411.9883], dtype=float32),
#  array([6753.6577], dtype=float32),
#  array([2164.2932], dtype=float32),
#  array([417.68478], dtype=float32),
#  array([415.0435], dtype=float32),
#  array([15369.615], dtype=float32),
#  array([4871.2], dtype=float32),
#  array([25.436844], dtype=float32),
#  array([13.207617], dtype=float32),
#  array([8515.626], dtype=float32),
#  array([5662.242], dtype=float32),
#  array([12.032938], dtype=float32),
#  array([18616.332], dtype=float32),
#  array([21452.264], dtype=float32),
#  array([22720.764], dtype=float32),
#  array([7975.996], dtype=float32),
#  array([383.19553], dtype=float32),
#  array([17371.695], dtype=float32),
#  array([17669.316], dtype=float32),
#  array([2234.2495], dtype=float32),
#  array([16109.939], dtype=float32),
#  array([12912.489], dtype=float32),
#  array([8239.104], dtype=float32),
#  array([8344.607], dtype=float32),
#  array([7502.006], dtype=float32),
#  array([836.6782], dtype=float32),
#  array([5905.269], dtype=float32),
#  array([9431.327], dtype=float32),
#  array([945.8308], dtype=float32),
#  array([19787.482], dtype=float32),
#  array([450.78522], dtype=float32),
#  array([16699.69], dtype=float32),
#  array([3676.878], dtype=float32),
#  array([12240.86], dtype=float32),
#  array([19298.078], dtype=float32),
#  array([12639.36], dtype=float32),
#  array([10465.231], dtype=float32),
#  array([11934.056], dtype=float32),
#  array([8048.6245], dtype=float32),
#  array([11950.893], dtype=float32),
#  array([1457.154], dtype=float32),
#  array([4792.029], dtype=float32),
#  array([15102.003], dtype=float32),
#  array([5172.496], dtype=float32),
#  array([93.89735], dtype=float32),
#  array([19556.488], dtype=float32),
#  array([2542.8406], dtype=float32),
#  array([27854.436], dtype=float32),
#  array([11284.636], dtype=float32),
#  array([953.5793], dtype=float32),
#  array([5379.6714], dtype=float32),
#  array([69.15747], dtype=float32),
#  array([2022.748], dtype=float32),
#  array([1563.0717], dtype=float32),
#  array([1115.9414], dtype=float32),
#  array([1439.9043], dtype=float32),
#  array([2259.0425], dtype=float32),
#  array([2988.6006], dtype=float32),
#  array([2382.7642], dtype=float32),
#  array([367.8954], dtype=float32),
#  array([16474.547], dtype=float32),
#  array([15941.126], dtype=float32),
#  array([3824.4167], dtype=float32),
#  array([12968.563], dtype=float32),
#  array([585.6965], dtype=float32),
#  array([11239.392], dtype=float32),
#  array([4612.038], dtype=float32),
#  array([17850.37], dtype=float32),
#  array([3797.8716], dtype=float32),
#  array([13265.397], dtype=float32),
#  array([196.99854], dtype=float32),
#  array([17403.727], dtype=float32),
#  array([531.719], dtype=float32),
#  array([12896.399], dtype=float32),
#  array([3063.9492], dtype=float32),
#  array([1203.2036], dtype=float32),
#  array([5527.323], dtype=float32),
#  array([13401.06], dtype=float32),
#  array([3703.798], dtype=float32),
#  array([288.26532], dtype=float32),
#  array([683.61005], dtype=float32),
#  array([16274.79], dtype=float32),
#  array([10945.271], dtype=float32),
#  array([14429.301], dtype=float32),
#  array([4343.5474], dtype=float32),
#  array([5930.7637], dtype=float32),
#  array([9146.211], dtype=float32),
#  array([131.72766], dtype=float32),
#  array([1182.6193], dtype=float32),
#  array([1318.0082], dtype=float32),
#  array([3051.3625], dtype=float32),
#  array([1827.6561], dtype=float32),
#  array([2429.8381], dtype=float32),
#  array([11541.887], dtype=float32),
#  array([1027.5118], dtype=float32),
#  array([10248.357], dtype=float32),
#  array([1127.7595], dtype=float32),
#  array([3066.054], dtype=float32),
#  array([14216.018], dtype=float32),
#  array([3926.9631], dtype=float32),
#  array([435.0027], dtype=float32),
#  array([17441.81], dtype=float32),
#  array([8821.698], dtype=float32),
#  array([3733.119], dtype=float32),
#  array([11312.601], dtype=float32),
#  array([358.79935], dtype=float32),
#  array([2298.6135], dtype=float32),
#  array([18213.31], dtype=float32),
#  array([13586.], dtype=float32),
#  array([7711.9946], dtype=float32),
#  array([178.93015], dtype=float32),
#  array([11023.239], dtype=float32),
#  array([5675.3345], dtype=float32),
#  array([22692.139], dtype=float32),
#  array([446.52637], dtype=float32),
#  array([10770.385], dtype=float32),
#  array([1329.4951], dtype=float32),
#  array([926.9433], dtype=float32),
#  array([3194.0525], dtype=float32),
#  array([9902.277], dtype=float32),
#  array([12666.509], dtype=float32),
#  array([2057.4573], dtype=float32),
#  array([14129.453], dtype=float32),
#  array([14195.67], dtype=float32),
#  array([5057.0664], dtype=float32),
#  array([11.320539], dtype=float32),
#  array([6724.8433], dtype=float32),
#  array([9334.275], dtype=float32),
#  array([5544.74], dtype=float32),
#  array([10467.041], dtype=float32),
#  array([7720.6226], dtype=float32),
#  array([4121.3174], dtype=float32),
#  array([154.98625], dtype=float32),
#  array([1210.784], dtype=float32),
#  array([10334.824], dtype=float32),
#  array([450.1429], dtype=float32),
#  array([1289.7985], dtype=float32),
#  array([3453.9653], dtype=float32),
#  array([18938.688], dtype=float32),
#  array([3706.5186], dtype=float32),
#  array([448.97305], dtype=float32),
#  array([11634.772], dtype=float32),
#  array([828.84515], dtype=float32),
#  array([3249.5032], dtype=float32),
#  array([1106.6973], dtype=float32),
#  array([19672.955], dtype=float32),
#  array([7700.2285], dtype=float32),
#  array([741.0166], dtype=float32),
#  array([16106.069], dtype=float32),
#  array([253.319], dtype=float32),
#  array([142.00725], dtype=float32),
#  array([93.89545], dtype=float32),
#  array([14013.706], dtype=float32),
#  array([8770.564], dtype=float32),
#  array([3042.1882], dtype=float32),
#  array([655.89526], dtype=float32),
#  array([110.86553], dtype=float32),
#  array([498.28857], dtype=float32),
#  array([2012.37], dtype=float32),
#  array([2227.7588], dtype=float32),
#  array([4229.7563], dtype=float32),
#  array([10634.305], dtype=float32),
#  array([1404.3129], dtype=float32),
#  array([6209.461], dtype=float32),
#  array([11506.652], dtype=float32),
#  array([15405.314], dtype=float32),
#  array([2372.5693], dtype=float32),
#  array([1635.3784], dtype=float32),
#  array([19668.92], dtype=float32),
#  array([13239.01], dtype=float32),
#  array([2570.0918], dtype=float32),
#  array([14580.769], dtype=float32),
#  array([13603.518], dtype=float32),
#  array([43.772896], dtype=float32),
#  array([1295.5737], dtype=float32),
#  array([3981.5564], dtype=float32),
#  array([2037.2625], dtype=float32),
#  array([13392.424], dtype=float32),
#  array([8685.731], dtype=float32),
#  array([13663.62], dtype=float32),
#  array([13601.549], dtype=float32),
#  array([15646.711], dtype=float32),
#  array([10463.938], dtype=float32),
#  array([9045.201], dtype=float32),
#  array([17180.428], dtype=float32),
#  array([8956.7295], dtype=float32),
#  array([453.3179], dtype=float32),
#  array([34625.49], dtype=float32),
#  array([1135.9408], dtype=float32),
#  array([14645.78], dtype=float32),
#  array([220.62944], dtype=float32),
#  array([4432.8896], dtype=float32),
#  array([6394.9976], dtype=float32),
#  array([13479.709], dtype=float32),
#  array([1527.3467], dtype=float32),
#  array([260.2525], dtype=float32),
#  array([16068.539], dtype=float32),
#  array([3723.9841], dtype=float32),
#  array([5703.847], dtype=float32),
#  array([20191.457], dtype=float32),
#  array([3525.8784], dtype=float32),
#  array([891.1517], dtype=float32),
#  array([209.6537], dtype=float32),
#  array([10360.257], dtype=float32),
#  array([1890.9675], dtype=float32),
#  array([12831.997], dtype=float32),
#  array([1282.363], dtype=float32),
#  array([2874.1213], dtype=float32),
#  array([6061.398], dtype=float32),
#  array([314.03732], dtype=float32),
#  array([15745.258], dtype=float32),
#  array([5642.113], dtype=float32),
#  array([13135.356], dtype=float32),
#  array([3361.4114], dtype=float32),
#  array([11719.369], dtype=float32),
#  array([20760.771], dtype=float32),
#  array([909.64685], dtype=float32),
#  array([6756.0605], dtype=float32),
#  array([12921.684], dtype=float32),
#  array([2749.557], dtype=float32),
#  array([9139.912], dtype=float32),
#  array([9957.308], dtype=float32),
#  array([326.31137], dtype=float32),
#  array([12577.473], dtype=float32),
#  array([423.1426], dtype=float32),
#  array([3807.1018], dtype=float32),
#  array([353.93622], dtype=float32),
#  array([1919.274], dtype=float32),
#  array([2356.7717], dtype=float32),
#  array([1034.0759], dtype=float32),
#  array([473.31104], dtype=float32),
#  array([2699.398], dtype=float32),
#  array([3143.7974], dtype=float32),
#  array([13184.228], dtype=float32),
#  array([1698.6982], dtype=float32),
#  array([13549.198], dtype=float32),
#  array([1434.976], dtype=float32),
#  array([7982.277], dtype=float32),
#  array([17278.154], dtype=float32),
#  array([576.68365], dtype=float32),
#  array([1408.4794], dtype=float32),
#  array([529.6429], dtype=float32),
#  array([6205.83], dtype=float32),
#  array([19692.402], dtype=float32),
#  array([11866.862], dtype=float32),
#  array([9092.733], dtype=float32),
#  array([2034.9208], dtype=float32),
#  array([20776.695], dtype=float32),
#  array([541.2131], dtype=float32),
#  array([261.9113], dtype=float32),
#  array([22684.766], dtype=float32),
#  array([8652.791], dtype=float32),
#  array([1525.4602], dtype=float32),
#  array([882.09436], dtype=float32),
#  array([579.61053], dtype=float32),
#  array([2885.902], dtype=float32),
#  array([7119.487], dtype=float32),
#  array([82.17034], dtype=float32),
#  array([6303.964], dtype=float32),
#  array([1699.5492], dtype=float32),
#  array([23138.719], dtype=float32),
#  array([3328.305], dtype=float32),
#  array([4010.0803], dtype=float32),
#  array([11581.876], dtype=float32),
#  array([1165.7222], dtype=float32),
#  array([24504.555], dtype=float32),
#  array([11357.243], dtype=float32),
#  array([3292.9863], dtype=float32),
#  array([43.04608], dtype=float32),
#  array([13679.441], dtype=float32),
#  array([1243.8782], dtype=float32),
#  array([9693.915], dtype=float32),
#  array([7230.852], dtype=float32),
#  array([16429.55], dtype=float32),
#  array([5446.5845], dtype=float32),
#  array([4768.3223], dtype=float32),
#  array([144.0602], dtype=float32),
#  array([2602.8855], dtype=float32),
#  array([21653.66], dtype=float32),
#  array([126.538086], dtype=float32),
#  array([51.763878], dtype=float32),
#  array([19240.094], dtype=float32),
#  array([446.83643], dtype=float32),
#  array([16792.326], dtype=float32),
#  array([11275.343], dtype=float32),
#  array([4945.265], dtype=float32),
#  array([2037.0034], dtype=float32),
#  array([17216.33], dtype=float32),
#  array([15940.282], dtype=float32),
#  array([908.64355], dtype=float32),
#  array([147.47878], dtype=float32),
#  array([4792.521], dtype=float32),
#  array([3392.2732], dtype=float32),
#  array([8134.264], dtype=float32),
#  array([200.17926], dtype=float32),
#  array([592.4185], dtype=float32),
#  array([68.301926], dtype=float32),
#  array([13148.871], dtype=float32),
#  array([7085.8716], dtype=float32),
#  array([20428.154], dtype=float32),
#  array([600.01636], dtype=float32),
#  array([17202.467], dtype=float32),
#  array([9972.751], dtype=float32),
#  array([1945.8833], dtype=float32),
#  array([21872.404], dtype=float32),
#  array([19035.645], dtype=float32),
#  array([4787.625], dtype=float32),
#  array([24991.883], dtype=float32),
#  array([8665.5], dtype=float32),
#  array([890.9954], dtype=float32),
#  array([7474.3774], dtype=float32),
#  array([17611.703], dtype=float32),
#  array([23659.299], dtype=float32),
#  array([48.678944], dtype=float32),
#  array([6517.1514], dtype=float32),
#  array([130.60904], dtype=float32),
#  array([10.761186], dtype=float32),
#  array([599.6699], dtype=float32),
#  array([32776.152], dtype=float32),
#  array([21029.727], dtype=float32),
#  array([6838.7104], dtype=float32),
#  array([18255.34], dtype=float32),
#  array([16502.17], dtype=float32),
#  array([1158.3202], dtype=float32),
#  array([10349.606], dtype=float32),
#  array([6883.47], dtype=float32),
#  array([1709.9823], dtype=float32),
#  array([7259.3657], dtype=float32),
#  array([8687.382], dtype=float32),
#  array([9315.954], dtype=float32),
#  array([5002.0923], dtype=float32),
#  array([11862.155], dtype=float32),
#  array([14945.841], dtype=float32),
#  array([5250.7676], dtype=float32),
#  array([14046.8955], dtype=float32),
#  array([13069.32], dtype=float32),
#  array([11.100189], dtype=float32),
#  array([54.44533], dtype=float32),
#  array([11379.943], dtype=float32),
#  array([7318.7354], dtype=float32),
#  array([16.852764], dtype=float32),
#  array([21246.68], dtype=float32),
#  array([22244.355], dtype=float32),
#  array([756.43604], dtype=float32),
#  array([1412.3446], dtype=float32),
#  array([3321.8374], dtype=float32),
#  array([14634.0625], dtype=float32),
#  array([946.6142], dtype=float32),
#  array([14320.114], dtype=float32),
#  array([16560.205], dtype=float32),
#  array([3.9587128], dtype=float32),
#  array([116.12061], dtype=float32),
#  array([206.21687], dtype=float32),
#  array([128.42374], dtype=float32),
#  array([262.57587], dtype=float32),
#  array([13042.676], dtype=float32),
#  array([18005.941], dtype=float32),
#  array([9285.919], dtype=float32),
#  array([14521.706], dtype=float32),
#  array([10928.467], dtype=float32),
#  array([5684.0303], dtype=float32),
#  array([618.372], dtype=float32),
#  array([16236.942], dtype=float32),
#  array([3561.2166], dtype=float32),
#  array([4365.3657], dtype=float32),
#  array([169.62582], dtype=float32),
#  array([10527.53], dtype=float32),
#  array([8047.391], dtype=float32),
#  array([12283.102], dtype=float32),
#  array([14484.772], dtype=float32),
#  array([18768.098], dtype=float32),
#  array([10784.37], dtype=float32),
#  array([14972.594], dtype=float32),
#  array([24433.283], dtype=float32),
#  array([220.97694], dtype=float32),
#  array([464.48016], dtype=float32),
#  array([7523.4736], dtype=float32),
#  array([1055.0314], dtype=float32),
#  array([4.5464926], dtype=float32),
#  array([454.5124], dtype=float32),
#  array([10702.889], dtype=float32),
#  array([5.4322534], dtype=float32),
#  array([7119.4263], dtype=float32),
#  array([566.3151], dtype=float32),
#  array([21376.629], dtype=float32),
#  array([1366.7722], dtype=float32),
#  array([1229.4359], dtype=float32),
#  array([5876.5527], dtype=float32),
#  array([17076.63], dtype=float32),
#  array([5520.624], dtype=float32),
#  array([14887.889], dtype=float32),
#  array([23518.518], dtype=float32),
#  array([8649.019], dtype=float32),
#  array([10937.112], dtype=float32),
#  array([7383.658], dtype=float32),
#  array([454.8876], dtype=float32),
#  array([9.6297035], dtype=float32),
#  array([72.10123], dtype=float32),
#  array([961.3003], dtype=float32),
#  array([16163.526], dtype=float32),
#  array([5158.0576], dtype=float32),
#  array([21169.104], dtype=float32),
#  array([941.36365], dtype=float32),
#  array([12174.934], dtype=float32),
#  array([251.45209], dtype=float32),
#  array([8.7777195], dtype=float32),
#  array([3.9680614], dtype=float32),
#  array([7674.3105], dtype=float32),
#  array([17121.277], dtype=float32),
#  array([18071.559], dtype=float32),
#  array([10077.034], dtype=float32),
#  array([9635.858], dtype=float32),
#  array([621.6723], dtype=float32),
#  array([3335.6216], dtype=float32),
#  array([9412.4375], dtype=float32),
#  array([189.09286], dtype=float32),
#  array([22734.01], dtype=float32),
#  array([605.65094], dtype=float32),
#  array([1934.4773], dtype=float32),
#  array([110.62533], dtype=float32),
#  array([6947.4204], dtype=float32),
#  array([17126.924], dtype=float32),
#  array([7.641313], dtype=float32),
#  array([30414.688], dtype=float32),
#  array([1062.7853], dtype=float32),
#  array([18920.158], dtype=float32),
#  array([6773.185], dtype=float32),
#  array([7.0945067], dtype=float32),
#  array([17104.486], dtype=float32),
#  array([17440.432], dtype=float32),
#  array([8334.582], dtype=float32),
#  array([6395.8516], dtype=float32),
#  array([18173.559], dtype=float32),
#  array([3019.8423], dtype=float32),
#  array([10321.349], dtype=float32),
#  array([19155.031], dtype=float32),
#  array([3509.2522], dtype=float32),
#  array([26588.16], dtype=float32),
#  array([311.70856], dtype=float32),
#  array([209.42471], dtype=float32),
#  array([446.1891], dtype=float32),
#  array([5927.952], dtype=float32),
#  array([18264.94], dtype=float32),
#  array([2349.0493], dtype=float32),
#  array([13142.622], dtype=float32),
#  array([26316.27], dtype=float32),
#  array([253.319], dtype=float32),
#  array([925.5621], dtype=float32),
#  array([2447.6897], dtype=float32),
#  array([627.0221], dtype=float32),
#  array([15005.648], dtype=float32),
#  array([15799.964], dtype=float32),
#  array([5034.2583], dtype=float32),
#  array([2476.6406], dtype=float32),
#  array([527.46704], dtype=float32),
#  array([8930.958], dtype=float32),
#  array([2137.7617], dtype=float32),
#  array([554.23553], dtype=float32),
#  array([1596.522], dtype=float32),
#  array([16901.492], dtype=float32),
#  array([24476.148], dtype=float32),
#  array([3961.8616], dtype=float32),
#  array([23490.941], dtype=float32),
#  array([131.93906], dtype=float32),
#  array([3546.0007], dtype=float32),
#  array([595.18427], dtype=float32),
#  array([3428.8816], dtype=float32),
#  array([3353.0361], dtype=float32),
#  array([698.3934], dtype=float32),
#  array([678.7142], dtype=float32),
#  array([123.444], dtype=float32),
#  array([8766.014], dtype=float32),
#  array([17136.318], dtype=float32),
#  array([9688.461], dtype=float32),
#  array([9103.148], dtype=float32),
#  array([2998.675], dtype=float32),
#  array([14257.063], dtype=float32),
#  array([2670.2334], dtype=float32),
#  array([45.41294], dtype=float32),
#  array([730.00696], dtype=float32),
#  array([16888.002], dtype=float32),
#  array([1218.4471], dtype=float32),
#  array([21557.307], dtype=float32),
#  array([32867.355], dtype=float32),
#  array([12188.312], dtype=float32),
#  array([1077.7417], dtype=float32),
#  array([1648.9602], dtype=float32),
#  array([14457.723], dtype=float32),
#  array([298.8293], dtype=float32),
#  array([4501.9688], dtype=float32),
#  array([10148.429], dtype=float32),
#  array([11528.864], dtype=float32),
#  array([5953.6484], dtype=float32),
#  array([11264.698], dtype=float32),
#  array([3690.3196], dtype=float32),
#  array([1395.1976], dtype=float32),
#  array([17544.797], dtype=float32),
#  array([5.3063216], dtype=float32),
#  array([1626.6829], dtype=float32),
#  array([3562.682], dtype=float32),
#  array([16254.242], dtype=float32),
#  array([4195.8345], dtype=float32),
#  array([3825.4775], dtype=float32),
#  array([1764.841], dtype=float32),
#  array([14155.54], dtype=float32),
#  array([5094.272], dtype=float32),
#  array([9658.969], dtype=float32),
#  array([6964.2637], dtype=float32),
#  array([16080.913], dtype=float32),
#  array([15196.67], dtype=float32),
#  array([382.52032], dtype=float32),
#  array([295.6641], dtype=float32),
#  array([6463.9077], dtype=float32),
#  array([3816.305], dtype=float32),
#  array([13964.199], dtype=float32),
#  array([390.92004], dtype=float32),
#  array([7995.3945], dtype=float32),
#  array([9172.614], dtype=float32),
#  array([5.416094], dtype=float32),
#  array([6867.732], dtype=float32),
#  array([3675.1265], dtype=float32),
#  array([12754.277], dtype=float32),
#  array([8244.628], dtype=float32),
#  array([759.91833], dtype=float32),
#  array([14463.162], dtype=float32),
#  array([2821.3728], dtype=float32),
#  array([3474.906], dtype=float32),
#  array([20413.152], dtype=float32),
#  array([19180.002], dtype=float32),
#  array([876.27246], dtype=float32),
#  array([1949.6643], dtype=float32),
#  array([2957.9238], dtype=float32),
#  array([4190.8604], dtype=float32),
#  array([5413.196], dtype=float32),
#  array([7514.999], dtype=float32),
#  array([5582.8564], dtype=float32),
#  array([17089.49], dtype=float32),
#  array([3233.6665], dtype=float32),
#  array([1724.3514], dtype=float32),
#  array([57.744205], dtype=float32),
#  array([9123.69], dtype=float32),
#  array([798.33765], dtype=float32),
#  array([4535.7446], dtype=float32),
#  array([962.3565], dtype=float32),
#  array([54.875652], dtype=float32),
#  array([3775.9731], dtype=float32),
#  array([1480.2236], dtype=float32),
#  array([18842.777], dtype=float32),
#  array([7114.684], dtype=float32),
#  array([16050.324], dtype=float32),
#  array([12148.331], dtype=float32),
#  array([12691.068], dtype=float32),
#  array([35.57488], dtype=float32),
#  array([19633.168], dtype=float32),
#  array([2460.5613], dtype=float32),
#  array([8099.635], dtype=float32),
#  array([506.8242], dtype=float32),
#  array([1415.6421], dtype=float32),
#  array([17855.854], dtype=float32),
#  array([70.593834], dtype=float32),
#  array([3275.8938], dtype=float32),
#  array([1433.7115], dtype=float32),
#  array([9810.744], dtype=float32),
#  array([14592.049], dtype=float32),
#  array([110.68996], dtype=float32),
#  array([8737.81], dtype=float32),
#  array([15749.339], dtype=float32),
#  array([1597.5647], dtype=float32),
#  array([119.99631], dtype=float32),
#  array([14018.976], dtype=float32),
#  array([1169.7797], dtype=float32),
#  array([10449.37], dtype=float32),
#  array([7026.621], dtype=float32),
#  array([17021.783], dtype=float32),
#  array([10270.502], dtype=float32),
#  array([12008.745], dtype=float32),
#  array([311.38885], dtype=float32),
#  array([200.1636], dtype=float32),
#  array([11356.807], dtype=float32),
#  array([394.80972], dtype=float32),
#  array([16887.764], dtype=float32),
#  array([14056.901], dtype=float32),
#  array([15154.421], dtype=float32),
#  array([16705.861], dtype=float32),
#  array([679.2854], dtype=float32),
#  array([24260.947], dtype=float32),
#  array([9855.165], dtype=float32),
#  array([15099.164], dtype=float32),
#  array([6374.736], dtype=float32),
#  array([23416.467], dtype=float32),
#  array([7200.018], dtype=float32),
#  array([1162.2122], dtype=float32),
#  array([1478.8661], dtype=float32),
#  array([16295.873], dtype=float32),
#  array([1210.8365], dtype=float32),
#  array([8673.203], dtype=float32),
#  array([11498.074], dtype=float32),
#  array([16822.984], dtype=float32),
#  array([1739.2], dtype=float32),
#  array([4.1716046], dtype=float32),
#  array([5357.7314], dtype=float32),
#  array([7417.1514], dtype=float32),
#  array([7501.793], dtype=float32),
#  array([5773.231], dtype=float32),
#  array([217.08978], dtype=float32),
#  array([1475.8729], dtype=float32),
#  array([16139.584], dtype=float32),
#  array([7593.225], dtype=float32),
#  array([28205.244], dtype=float32),
#  array([1201.9333], dtype=float32),
#  array([10016.622], dtype=float32),
#  array([1081.4623], dtype=float32),
#  array([18157.5], dtype=float32),
#  array([935.10675], dtype=float32),
#  array([13615.925], dtype=float32),
#  array([1886.5112], dtype=float32),
#  array([1567.257], dtype=float32),
#  array([1585.3647], dtype=float32),
#  array([17449.064], dtype=float32),
#  array([1021.34033], dtype=float32),
#  array([4490.8926], dtype=float32),
#  array([6184.588], dtype=float32),
#  array([14805.351], dtype=float32),
#  array([11148.602], dtype=float32),
#  array([12311.507], dtype=float32),
#  array([674.5979], dtype=float32),
#  array([166.42476], dtype=float32),
#  array([538.069], dtype=float32),
#  array([3927.3694], dtype=float32),
#  array([6384.392], dtype=float32),
#  array([11.808028], dtype=float32),
#  array([1885.9943], dtype=float32),
#  array([8975.786], dtype=float32),
#  array([2623.182], dtype=float32),
#  array([8742.257], dtype=float32),
#  array([62.471214], dtype=float32),
#  array([5074.184], dtype=float32),
#  array([9015.554], dtype=float32),
#  array([882.6291], dtype=float32),
#  array([6432.338], dtype=float32),
#  array([10811.362], dtype=float32),
#  array([15250.805], dtype=float32),
#  array([445.26184], dtype=float32),
#  array([1378.6296], dtype=float32),
#  array([13654.824], dtype=float32),
#  array([17476.201], dtype=float32),
#  array([11747.112], dtype=float32),
#  array([474.11115], dtype=float32),
#  array([7352.5093], dtype=float32),
#  array([8018.0938], dtype=float32),
#  array([4107.4375], dtype=float32),
#  array([7011.899], dtype=float32),
#  array([3073.6177], dtype=float32),
#  array([1539.021], dtype=float32),
#  array([3642.0989], dtype=float32),
#  array([4508.7866], dtype=float32),
#  array([41.517063], dtype=float32),
#  array([17594.414], dtype=float32),
#  array([18637.09], dtype=float32),
#  array([586.34674], dtype=float32),
#  array([16328.937], dtype=float32),
#  array([257.08655], dtype=float32),
#  array([910.41907], dtype=float32),
#  array([3102.6257], dtype=float32),
#  array([6048.3315], dtype=float32),
#  array([6290.1885], dtype=float32),
#  array([70.702576], dtype=float32),
#  array([1041.5797], dtype=float32),
#  array([16917.607], dtype=float32),
#  array([19196.268], dtype=float32),
#  array([1300.2709], dtype=float32),
#  array([842.4661], dtype=float32),
#  array([878.7754], dtype=float32),
#  array([394.5888], dtype=float32),
#  array([16602.95], dtype=float32),
#  array([8012.371], dtype=float32),
#  array([248.31767], dtype=float32),
#  array([753.0253], dtype=float32),
#  array([10497.41], dtype=float32),
#  array([10517.188], dtype=float32),
#  array([4961.114], dtype=float32),
#  array([64.79022], dtype=float32),
#  array([12702.512], dtype=float32),
#  array([4790.1475], dtype=float32),
#  array([1417.4413], dtype=float32),
#  array([15109.521], dtype=float32),
#  array([1310.6215], dtype=float32),
#  array([290.63165], dtype=float32),
#  array([15578.657], dtype=float32),
#  array([23665.506], dtype=float32),
#  array([9462.671], dtype=float32),
#  array([15322.269], dtype=float32),
#  array([20545.87], dtype=float32),
#  array([8.365283], dtype=float32),
#  array([8027.025], dtype=float32),
#  array([22692.896], dtype=float32),
#  array([22823.143], dtype=float32),
#  array([2734.1719], dtype=float32),
#  array([21484.418], dtype=float32),
#  array([12632.861], dtype=float32),
#  array([2443.2634], dtype=float32),
#  array([4.865738], dtype=float32),
#  array([1540.4733], dtype=float32),
#  array([89.4859], dtype=float32),
#  array([15015.923], dtype=float32),
#  array([3579.0933], dtype=float32),
#  array([16701.201], dtype=float32),
#  array([11880.403], dtype=float32),
#  array([3037.7993], dtype=float32),
#  array([1509.3093], dtype=float32),
#  array([16854.398], dtype=float32),
#  array([11087.9795], dtype=float32),
#  array([4229.47], dtype=float32),
#  array([38.47836], dtype=float32),
#  array([13897.081], dtype=float32),
#  array([8507.564], dtype=float32),
#  array([10064.586], dtype=float32),
#  array([301.6294], dtype=float32),
#  array([5296.4673], dtype=float32),
#  array([21267.105], dtype=float32),
#  array([168.3193], dtype=float32),
#  array([7648.0825], dtype=float32),
#  array([5053.216], dtype=float32),
#  array([7450.6274], dtype=float32),
#  array([15919.387], dtype=float32),
#  array([7035.0527], dtype=float32),
#  array([8087.608], dtype=float32),
#  array([2659.2615], dtype=float32),
#  array([437.41135], dtype=float32),
#  array([1921.2714], dtype=float32),
#  array([14346.742], dtype=float32),
#  array([5342.548], dtype=float32),
#  array([585.6965], dtype=float32),
#  array([3329.7554], dtype=float32),
#  array([5789.685], dtype=float32),
#  array([153.95306], dtype=float32),
#  array([22519.51], dtype=float32),
#  array([20293.12], dtype=float32),
#  array([14954.096], dtype=float32),
#  array([6685.614], dtype=float32),
#  array([5342.289], dtype=float32),
#  array([3621.0723], dtype=float32),
#  array([10740.631], dtype=float32),
#  array([213.18666], dtype=float32),
#  array([2359.8564], dtype=float32),
#  array([11698.219], dtype=float32),
#  array([1226.4662], dtype=float32),
#  array([2598.9666], dtype=float32),
#  array([76.9796], dtype=float32),
#  array([11042.361], dtype=float32),
#  array([7507.9067], dtype=float32),
#  array([843.3529], dtype=float32),
#  array([49.8224], dtype=float32)]

# %%
#colors = ['blue','red','green']
#labelNames = ['e','μ','π+']

fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter(trueE, predE, s=10, alpha=0.5, edgecolors='none')
ax.set_xlabel('True energy [MeV]')
ax.set_ylabel('Reconstructed energy [MeV]')
ax.set_xlim(0,1140.)
ax.set_ylim(0,1500.)

#ax.legend()
plt.show()

# %%
with torch.no_grad():
    Nrows = 5
    iter_test_loader = iter(test_loader)
    
    trueE = []
    totalQ = []
    trueLabel = []
    for r in range(Nrows):
        test_data = next(iter_test_loader)
        
        blob.net.eval()
        # Data and label
        blob.data  = test_data['event_data']
        blob.label = test_data['label']
        blob.energies = test_data['energies']

        res = forward(blob,False)
        
        trueE.extend(blob.energies[:,0])
        totalQ.extend(np.sum(blob.data[:,:,:,0], axis=(1,2)))
        
        trueLabel.extend(blob.label)

    del iter_test_loader

plt.scatter(trueE, totalQ, c=trueLabel, alpha=0.5)
plt.xlabel('True energy [MeV]')
plt.ylabel('Total charge')
plt.show()

# %%
#colors = ['blue','red','green']
#labelNames = ['e','μ','π+']

fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter(trueE, totalQ, s=10, alpha=0.5, edgecolors='none')
ax.set_xlabel('True energy [MeV]')
ax.set_ylabel('Total charge')
ax.set_xlim(0,1140.)
ax.set_ylim(0,12000.)

#ax.legend()
plt.show()

# %%
with torch.no_grad():
    Nrows = 5
    iter_test_loader = iter(test_loader)
    
    trueE = []
    totalQ = []
    predE = []
    trueLabel = []
    for r in range(Nrows):
        test_data = next(iter_test_loader)
        
        blob.net.eval()
        # Data and label
        blob.data  = test_data['event_data']
        blob.label = test_data['label']
        blob.energies = test_data['energies']

        res = forward(blob,False)
        
        trueE.extend(blob.energies[:,0])
        predE.extend(res['predEnergy'])
        totalQ.extend(np.sum(blob.data[:,:,:,0], axis=(1,2)))
        
        trueLabel.extend(blob.label)

    del iter_test_loader

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter(np.array(totalQ)/np.array(trueE), np.array(predE)[:,0]/np.array(trueE), s=10, alpha=0.5, edgecolors='none')
ax.set_xlabel('Total charge / True energy [1/MeV]')
ax.set_ylabel('Reconstructed energy / True energy')
ax.set_xlim(0,20.)
ax.set_ylim(0,2.)

#ax.legend()
plt.show()

# %%
with torch.no_grad():
    Nrows = 5
    iter_test_loader = iter(test_loader)
    
    trueE = []
    trueX = []
    trueY = []
    trueZ = []
    totalQ = []
    predE = []
    trueLabel = []
    for r in range(Nrows):
        test_data = next(iter_test_loader)
        
        blob.net.eval()
        # Data and label
        blob.data  = test_data['event_data']
        blob.label = test_data['label']
        blob.energies = test_data['energies']
        blob.positions = test_data['positions']

        res = forward(blob,False)
        
        trueE.extend(blob.energies[:,0])
        trueX.extend(blob.positions[:,0,0])
        trueY.extend(blob.positions[:,0,1])
        trueZ.extend(blob.positions[:,0,2])
        
        predE.extend(res['predEnergy'])
        totalQ.extend(np.sum(blob.data[:,:,:,0], axis=(1,2)))
        
        trueLabel.extend(blob.label)

    del iter_test_loader

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter(np.array(trueZ), np.array(predE)[:,0]/np.array(trueE), s=10, alpha=0.5, edgecolors='none')
ax.set_xlabel('True z [cm]')
ax.set_ylabel('Reconstructed energy / True energy')
ax.set_xlim(-2000.,2000.)
ax.set_ylim(0,2.)

#ax.legend()
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter((np.array(trueX)**2 + np.array(trueY)**2)/(100.**2), np.array(predE)[:,0]/np.array(trueE), s=10, alpha=0.5, edgecolors='none')
ax.set_xlabel('True rho^2 [m^2]')
ax.set_ylabel('Reconstructed energy / True energy')
ax.set_xlim(0.,300.)
ax.set_ylim(0,2.)

#ax.legend()
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter((np.array(trueX)**2 + np.array(trueY)**2)/(100.**2), np.array(trueZ)/100., s=100.*np.abs(np.array(predE)[:,0]/np.array(trueE)-1.), alpha=0.5, edgecolors='none')
ax.set_xlabel('True rho^2 [m^2]')
ax.set_ylabel('True z [m]')
ax.set_xlim(0.,300.)
ax.set_ylim(-20.,20.)
ax.set_title('Size = absolute relative deviation')

#ax.legend()
plt.show()

# %%
with torch.no_grad():
    Nrows = 40
    iter_test_loader = iter(test_loader)
    
    trueE = []
    trueX = []
    trueY = []
    trueZ = []
    trueDx = []
    trueDy = []
    trueDz = []
    totalQ = []
    predE = []
    trueLabel = []
    for r in range(Nrows):
        test_data = next(iter_test_loader)
        
        blob.net.eval()
        # Data and label
        blob.data  = test_data['event_data']
        blob.label = test_data['label']
        blob.energies = test_data['energies']
        blob.positions = test_data['positions']
        blob.directions = test_data['directions']

        res = forward(blob,False)
        
        trueE.extend(blob.energies[:,0])
        trueX.extend(blob.positions[:,0,0])
        trueY.extend(blob.positions[:,0,1])
        trueZ.extend(blob.positions[:,0,2])
        trueDx.extend(blob.directions[:,0,0])
        trueDy.extend(blob.directions[:,0,1])
        trueDz.extend(blob.directions[:,0,2])
        
        predE.extend(res['predEnergy'])
        totalQ.extend(np.sum(blob.data[:,:,:,0], axis=(1,2)))
        
        trueLabel.extend(blob.label)

    del iter_test_loader
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-42-d904c4ce5989> in <module>
#      14     trueLabel = []
#      15     for r in range(Nrows):
# ---> 16         test_data = next(iter_test_loader)
#      17
#      18         blob.net.eval()
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     539         if self.batches_outstanding == 0:
#     540             self._shutdown_workers()
# --> 541             raise StopIteration
#     542
#     543         while True:
#
# StopIteration:

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter((np.array(trueX)**2 + np.array(trueY)**2)/(100.**2), np.array(trueZ)/100., s=40.*np.sqrt(np.abs(np.array(predE)[:,0]/np.array(trueE)-1.)), alpha=0.4, edgecolors='none')
ax.set_xlabel('True rho^2 [m^2]')
ax.set_ylabel('True z [m]')
ax.set_xlim(0.,300.)
ax.set_ylim(-20.,20.)
ax.set_title('Size = absolute relative deviation')

#ax.legend()
plt.show()

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

ax = axes
ax.scatter((np.array(trueX)*np.array(trueDx) + np.array(trueY)*np.array(trueDy) + np.array(trueZ)*np.array(trueDz)), np.array(predE)[:,0]/np.array(trueE), s=10, alpha=0.5, edgecolors='none')
ax.set_xlabel('True pos * dir [cm]')
ax.set_ylabel('Reconstructed energy / True energy')
ax.set_xlim(0.,300.)
ax.set_ylim(0,2.)

#ax.legend()
plt.show()
