# %%
import h5py
f = h5py.File('event_dump.h5','r')
event_data = f['event_data'][:]

# %%
from __future__ import print_function
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(event_data[0,:,:,0])

# %%
plt.imshow(event_data[0,:,:,1])

# %%
plt.imshow(event_data[1,:,:,0])

# %%
plt.imshow(event_data[2,:,:,0])

# %%
plt.imshow(event_data[3,:,:,0])

# %%
plt.imshow(event_data[4,:,:,0])

# %%
plt.imshow(f['mGridPmt'][:])

# %%
plt.imshow(f['mGridX'][:])

# %%
plt.imshow(f['mGridY'][:])

# %%
plt.imshow(f['mGridDirX'][:])

# %%
plt.imshow(f['mGridDirY'][:])

# %%
plt.imshow(f['mGridDirZ'][:])

# %%
f.keys()
# Out:
# <KeysViewHDF5 ['directions', 'energies', 'event_data', 'event_ids', 'mGridDirX', 'mGridDirY', 'mGridDirZ', 'mGridPmt', 'mGridX', 'mGridY', 'mGridZ', 'pids', 'positions']>

# %%
f['directions'][1:10]
# Out:
# array([[[-9.5940703e-01, -3.6732051e-06,  2.8202516e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 9.7156101e-01, -3.6732051e-06, -2.3678936e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 1.3230100e-01, -3.6732051e-06,  9.9120957e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 9.5421427e-01, -3.6732051e-06, -2.9912391e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-2.9468285e-02, -3.6732051e-06, -9.9956572e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-6.2008268e-01, -3.6732051e-06,  7.8453648e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[-9.7026426e-01, -3.6732051e-06, -2.4204805e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
#        [[ 6.3836414e-01, -3.6732051e-06, -7.6973450e-01],
#         [ 0.0000000e+00,  0.0000000e+00,  0.0000000e+00]],
#
# ...

# %%
f['energies'][1:10,0]
# Out:
# array([ 391.80692, 1007.9331 , 1260.8688 ,  710.94147,  622.5436 ,
#         711.0593 ,  370.2205 , 1256.7513 , 1238.1766 ], dtype=float32)

# %%
f['pids'][1:10,0]
# Out:
# array([13, 13, 13, 13, 13, 13, 13, 13, 13], dtype=int32)

# %%
f['labels'][1:10]
# Out:
# array([2, 2, 2, 2, 2, 2, 2, 2, 2], dtype=int32)
