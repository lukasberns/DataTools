# %%
from __future__ import print_function
import numpy as np
import torch 
import h5py
import matplotlib.pyplot as plt
# %matplotlib inline

def geometricPad(grid, pad=1):
  M = grid.shape[2]; # 0:batchsize, 1:channels, 2:width, 3:height
  M_new = pad+M+pad;
  new_shape = (grid.shape[0], grid.shape[1], M_new, M_new)
  grid_new = grid.new_zeros(new_shape);
  grid_new[:,:,pad:M+pad,pad:M+pad] = grid;
  grid_new[:,:,0:pad,pad:(M+pad)] = grid[:,:,:,0:pad].flip(-1).transpose(-1,-2);
  grid_new[:,:,pad:(M+pad),0:pad] = grid[:,:,0:pad,:].flip(-2).transpose(-1,-2);
  grid_new[:,:,(M+pad):(M+pad+pad),(pad):(M+pad)] = grid[:,:,:,(M-pad):].flip(-1).transpose(-1,-2);
  grid_new[:,:,pad:(M+pad),(M+pad):(M+pad+pad)] = grid[:,:,(M-pad):,:].flip(-2).transpose(-1,-2);
  return(grid_new);

# %%
class Taylorizer:
    """Perform taylor expansion of tensor using pre-computed expansion weights"""
    def __init__(self, mGridPmt, mGridCoord, vectorStartIndices, pad=1, Lambda=0.5):
        """
        mGridPmt:   numpy array with (Height,Width) only significance is
                    1. value should be unique for each grid site
                    2. if no PMT exists, set to -1
        mGridCoord: numpy array with (Ncoords,Height,Width)
        vectorStartIndices: array with the start indices of xyz vectors in Ncoords, e.g.
                            for [x,y,z,dirx,diry,dirz] pass [0,3] which treats (x,y,z) and (dirx,diry,dirz)
                            as a vector
        pad:        the taylor expansion will be performed on a grid with sides 2*pad+1
        Lambda:     the regularization strength. should be something of order the differences in mGridCoord
        """
        
        self.mGridPmt   = mGridPmt
        self.mGridCoord = mGridCoord
        self.vectorStartIndices = vectorStartIndices
        self.pad = pad
        self.Lambda = Lambda
        self.rotPhi = 0.
        self.AA = self.computeTaylorWeights()
    
    def cuda(self):
        self.AA = self.AA.cuda()
    
    def cpu(self):
        self.AA = self.AA.cpu()
        
    def __call__(self, inputs):
        return self.taylorize(inputs)

    def computeTaylorWeights(self):
        pad = self.pad
        mGridPmt = self.mGridPmt
        mGridCoord = self.mGridCoord

        Ncoords = mGridCoord.shape[0]
        Ntaylor = 1 + Ncoords # + (Ncoords*(Ncoords+1))//2
        self.Ntaylor = Ntaylor

        M = mGridPmt.shape[0]
        mGridI = np.reshape(np.repeat(np.arange(M),M), (M,M))
        mGridJ = mGridI.transpose()

        Nshift = 2*pad+1
        dij = np.reshape(np.repeat(np.arange(-pad,pad+1),Nshift), (Nshift,Nshift));
        dis = dij.flatten()
        djs = dij.transpose().flatten();
        Nsites = dis.size;
        
        self.dis = dis
        self.djs = djs
        self.Nsites = Nsites

        mGridPmtpad = geometricPad(torch.tensor(mGridPmt).unsqueeze(0).unsqueeze(0), pad).squeeze(0).squeeze(0).numpy();
        mGridIpad = geometricPad(torch.tensor(mGridI).unsqueeze(0).unsqueeze(0), pad).squeeze(0).squeeze(0).numpy();
        mGridJpad = geometricPad(torch.tensor(mGridJ).unsqueeze(0).unsqueeze(0), pad).squeeze(0).squeeze(0).numpy();

        mGridCoordPad = geometricPad(torch.tensor(mGridCoord).unsqueeze(0), pad).squeeze(0).numpy();


        mGridAA2 = np.zeros((M,M,Nshift,Nshift,Ntaylor))

        pmtI1 = mGridPmt[:,:]; # index in tank.pmt

        x      = np.zeros((Ncoords,M,M,Nsites));     # coordinates for each direction
        skip   = np.zeros((M,M,Nsites), dtype=bool); # for each direction whether we should skip or not
        processedPmtI2s = np.zeros((M,M,Nsites), dtype=int) - 1;

        for diji in range(Nsites):
            di = dis[diji]
            dj = djs[diji]
            # i2 = mGridIpad[pad+di:pad+M+di,pad+dj:pad+M+dj];
            # j2 = mGridJpad[pad+di:pad+M+di,pad+dj:pad+M+dj];
            pmtI2 = mGridPmtpad[(pad+di):(pad+M+di),(pad+dj):(pad+M+dj)];
            processedPmtI2s[:,:,diji] = pmtI2;

            skip[:,:,diji] = np.logical_or(np.equal(pmtI1,-1), np.equal(pmtI2,-1));
            for prev_diji in range(diji):
                skip[:,:,diji] = np.logical_or(skip[:,:,diji], np.equal(processedPmtI2s[:,:,prev_diji],pmtI2));

            x[:,:,:,diji] = mGridCoordPad[:,(pad+di):(pad+M+di),(pad+dj):(pad+M+dj)] - mGridCoord; # 

        # x: (Ncoords,M,M,Nsites)
        # print('x.shape:', x.shape)
        # X: (Ntaylor,M,M,Nsites)
        Xlist = [np.expand_dims(np.ones(x.shape[1:]),0),x]
        #for i in range(Ncoords):
        #    Xlist.append(np.stack([x[i,:,:,:] for j in range(Ncoords-i)]) * x[i:,:,:,:])
        X = np.concatenate(Xlist)
        # print('X.shape:', X.shape)
        X = np.where(np.expand_dims(skip, 0), 0., X);

        # regularization strength
        Lambda = self.Lambda; # this should be somewhat smaller than typical values of x

        MA = np.zeros((M,M,Nsites,Nsites));
        for k in range(Nsites):
            for j in range(Nsites):
                MA[:,:,k,j] = np.add(np.sum(X[:,:,:,k]*X[:,:,:,j], axis=0), Lambda**2 * (k==j));
            # clear skip entries
            MA[:,:,k,:] = np.where(np.expand_dims(skip[:,:,k],-1), 0., MA[:,:,k,:]);
            MA[:,:,:,j] = np.where(np.expand_dims(skip[:,:,j],-1), 0., MA[:,:,:,j]);
            # set diagonal:
            MA[:,:,k,k] = np.where(skip[:,:,k], 1., MA[:,:,k,k]);

        #print('MA.shape:',MA.shape)
        #print(MA[0,1,:,:])
        #print(np.linalg.inv(MA[0,1,:,:]))
        print("starting inversion... (may take a few seconds)")
        AA = np.einsum('hwsi,thwi->thws', np.linalg.inv(MA), X)
        print("done")
        # print('AA.shape:', AA.shape)
        return torch.tensor(AA, dtype=torch.float)
    
    def taylorize(self, inputs):
        Batches = inputs.shape[0]
        ChIn    = inputs.shape[1]
        Height  = inputs.shape[2]
        Width   = inputs.shape[3]
        tGridAA = self.AA

        inputsPad = geometricPad(inputs, self.pad); # (B,C,W,H)
        tayloredInput = inputs.new_zeros((Batches, self.Ntaylor, ChIn, Height, Width))
        
        # we use new_zeros and set diagonal to 1, because there is no new_eye method
        rotMatrix = inputs.new_zeros(self.Ntaylor, self.Ntaylor)
        for d in range(self.Ntaylor):
            rotMatrix[d,d] = 1.
        
        for startIndex in self.vectorStartIndices:
            startIndex = 1 + startIndex # the 1 is offset due to scalar
            d_x = 0
            d_y = 1
            rotMatrix[startIndex+d_x,startIndex+d_x] =  np.cos(self.rotPhi);
            rotMatrix[startIndex+d_x,startIndex+d_y] =  np.sin(self.rotPhi); # this is an inverse rotation because w is covariant
            rotMatrix[startIndex+d_y,startIndex+d_x] = -np.sin(self.rotPhi);
            rotMatrix[startIndex+d_y,startIndex+d_y] =  np.cos(self.rotPhi);
        
        #print('tGridAA.shape:', tGridAA.shape)
        #print('tayloredInput.shape:', tayloredInput.shape)
        #print('inputsPad.shape:', inputsPad.shape)
        for k in range(self.Nsites):
            # shift grid according to position (without copying the data)
            inputsPadD1 = torch.narrow(inputsPad,   2, self.pad+int(self.dis[k]), Height)
            inputsPadD2 = torch.narrow(inputsPadD1, 3, self.pad+int(self.djs[k]), Width )
            # fill
            # d,e: directional index (Ntaylor)
            # i,j: grid indices
            # b: event in batch
            # c: channel
            out = torch.add(tayloredInput, torch.einsum('dij,bcij->bdcij', tGridAA[:,:,:,k], inputsPadD2))
            tayloredInput = out
        
        if self.rotPhi != 0.:
            org = tayloredInput
            tayloredInput = torch.einsum('bdcij,ed->becij', org, rotMatrix).contiguous()
            #tayloredInput = out
        
        #print('tayloredInput.shape', tayloredInput.shape, 'to', (Batches, self.Ntaylor*ChIn, Height, Width))
        return tayloredInput.view(Batches, self.Ntaylor*ChIn, Height, Width)
    
    def pool2d(self, kernel_size, pad=-1, Lambda=-1.):
        """
        Return new Taylorizer that can be used for the result of a 2d pool operation with given kernel size.
        kernel_size: e.g. for 2x2 max-pooling use (2,2)
        pad:    if unset (-1)  use same as current
        Lambda: if unset (-1.) use same as current
        """
        mGridPmt1   = torch.nn.functional.max_pool2d(torch.tensor(self.mGridPmt  ).to(torch.float).unsqueeze(0), kernel_size).squeeze(0).to(torch.long).numpy()
        mGridFilled1 = torch.nn.functional.avg_pool2d(torch.tensor((self.mGridPmt >= 0).astype(float)).unsqueeze(0), kernel_size).squeeze(0).numpy()
        
        mGridCoord1 = torch.nn.functional.avg_pool2d(torch.tensor(self.mGridCoord), kernel_size).numpy()
        mGridCoord1 /= mGridFilled1 # correct average for missing positions
        
        if (pad < 0):
            pad = self.pad
        if (Lambda < 0.):
            Lambda = self.Lambda
        
        return Taylorizer(mGridPmt1, mGridCoord1, self.vectorStartIndices, pad=pad, Lambda=Lambda)

# %%
f = h5py.File('/home/lukasb/projects/rpp-tanaka-ab/lukasb/watchmal/20190808-uniisoflat/1Rmu-blacksheet/wc-0-bch1.h5','r')
event_data = f['event_data'][:]

# %%
mGridPmt = f['mGridPmt'][()]
mGridCoord = np.stack([
    f['mGridX'][()]/20.,
    f['mGridY'][()]/20.,
    f['mGridZ'][()]/20.,
    f['mGridDirX'][()],
    f['mGridDirY'][()],
    f['mGridDirZ'][()]
])
mGridVectorStartIndices = [0,3]

taylor0 = Taylorizer(mGridPmt, mGridCoord, mGridVectorStartIndices, pad=1, Lambda=1.)
# Out:
# starting inversion... (may take a few seconds)
# done

# %%
def imshowRdBu(ax,img):
    minmax = max(torch.max(img),-torch.min(img))
    return ax.imshow(-img,cmap='RdBu',vmin=-minmax,vmax=minmax)

# %%
# filters = torch.randn(Cout,Cin,Hflt,Wflt);
inputs = torch.tensor(event_data[(0,5),:,:,0]).unsqueeze(1);
tayloredInput = taylor0(inputs)

for ev in range(tayloredInput.shape[0]):
    print(ev)
    taylorTitles = ['1','x','y','z','dir_x','dir_y','dir_z']
    fig, axes = plt.subplots(1, taylor0.Ntaylor, figsize=(16,8),facecolor='w')
    for itaylor in range(taylor0.Ntaylor):
        imshowRdBu(axes[itaylor], tayloredInput[ev,itaylor,:,:]); axes[itaylor].set_title(taylorTitles[itaylor])
    plt.show()
# Out:
# 0
# 1

# %% [markdown]
# ## Train network for classification, but with timing information

# %%
from torch.utils.data import Dataset, DataLoader

class H5Dataset(Dataset):

    def __init__(self, files, transform=None, flavour=None, limit_num_files=0, start_fraction=0., use_fraction=1.0):
        """                                                                                                                                             
        Args: data_dirs ... a list of data directories to find files (up to 10 files read from each dir)                                                
              transform ... a function applied to pre-process data                                                                                      
              flavour ..... a string that is required to be present in the filename                                                                     
              limit_num_files ... an integer limiting number of files to be taken per data directory                                                    
              start_fraction ... a floating point fraction (0.0=>1.0) to specify which entry to start reading (per file)                                
              use_fraction ..... a floating point fraction (0.0=>1.0) to specify how much fraction of a file to be read out (per file)                  
        """
        self._transform = transform
        self._files = []

        # Check input fractions makes sense                                                                                                             
        assert start_fraction >= 0. and start_fraction < 1.
        assert use_fraction > 0. and use_fraction <= 1.
        assert (start_fraction + use_fraction) <= 1.

        # Load files (up to 10) from each directory in data_dirs list                                                                                   
        # for d in data_dirs:
        #     file_list = [ os.path.join(d,f) for f in os.listdir(d) if flavour is None or flavour in f ]
        #     if limit_num_files: file_list = file_list[0:limit_num_files]
        #     self._files += file_list
        self._files = files

        self._file_handles = [None] * len(self._files)
        self._event_to_file_index  = []
        self._event_to_entry_index = []
        import h5py
        for file_index, file_name in enumerate(self._files):
            f = h5py.File(file_name,mode='r')
            data_size = f['event_data'].shape[0]
            start_entry = int(start_fraction * data_size)
            num_entries = int(use_fraction * data_size)
            self._event_to_file_index += [file_index] * num_entries
            self._event_to_entry_index += range(start_entry, start_entry+num_entries)
            f.close()

    def __len__(self):
        return len(self._event_to_file_index)

    def __getitem__(self,idx):
        file_index = self._event_to_file_index[idx]
        entry_index = self._event_to_entry_index[idx]
        if self._file_handles[file_index] is None:
            import h5py
            self._file_handles[file_index] = h5py.File(self._files[file_index],mode='r')
        fh = self._file_handles[file_index]
        label = fh['labels'][entry_index]
        #labelTranslation = [-1,0,1,-1,2] # make sure that labels 1,2,4 get values 0,1,2
        if label == 1: # electron
            label = 0
        elif label == 2: # muon
            label = 1
        elif label == 4: # pip
            label = 2
        else:
            print('Unknown label', label, 'for entry_index', entry_index, 'treating as label=0')
            label = 0
        
        # try:
        #     label = labelTranslation[label]
        # except IndexError:
        #     print('IndexError at entry', entry_index, 'label in file was', fh['labels'][entry_index], 'translations are', labelTranslation)
        #     raise
        
        event_data = fh['event_data'][entry_index]
        return event_data[:,:,0:2],label,idx

def HKCollate(batch):
    data  = np.stack([sample[0] for sample in batch])
    label = [sample[1] for sample in batch]
    idx   = [sample[2] for sample in batch]
    rndmRot = np.random.uniform(0., 2*np.pi)
    return data,label,idx,rndmRot

# %%
# also add more data

#mcdir = '/home/lukasb/projects/rpp-tanaka-ab/lukasb/watchmal/20190808-uniisoflat'
mcdir = '/home/lukasb/scratch/20190808-uniisoflat'
wallmat = 'blacksheet'
pnames = ('e','mu','pip')
files = ['%s/1R%s-%s/wc-0-bch%d.h5' % (mcdir,pname,wallmat,bch+1) for bch in range(5) for pname in pnames]

train_ds = H5Dataset(files,start_fraction=0.0,use_fraction=0.5);
test_ds  = H5Dataset(files,start_fraction=0.5,use_fraction=0.1);

# for training
train_loader=DataLoader(train_ds,batch_size= 64,shuffle=True,num_workers=4,collate_fn=HKCollate)
# for validation
test_loader =DataLoader( test_ds,batch_size=200,shuffle=True,num_workers=2,collate_fn=HKCollate)

# %%
class GeomBNConv2d(torch.nn.Module):
    def __init__(self,Cin,Cout,pad):
        super(GeomBNConv2d, self).__init__()
        self.Cin = Cin
        self.Cout = Cout
        self.pad = pad
        self.batchNorm2d = torch.nn.BatchNorm2d(Cin)
        self.conv2d = torch.nn.Conv2d(Cin,Cout,2*self.pad+1)
 
    def forward(self, x):
        x = self.batchNorm2d(x)
        inputsPad = geometricPad(x, self.pad); # (B,C,W,H)
        return self.conv2d(inputsPad)

class TaylorBNConv2d(torch.nn.Module):
    def __init__(self,Cin,Cout,taylor):
        super(TaylorBNConv2d, self).__init__()
        self.Cin = Cin
        self.Cout = Cout
        self.taylor = taylor
        self.batchNorm2d = torch.nn.BatchNorm2d(Cin*taylor.Ntaylor)
        self.conv2d = torch.nn.Conv2d(Cin*taylor.Ntaylor,Cout,1)
 
    def forward(self, x):
        x = self.taylor(x)
        x = self.batchNorm2d(x)
        x = self.conv2d(x)
        return x
    
    # the default implementation of cpu() and cuda() only passes this along to nn.Module instances
    # since self.AA is a tensor, we need to take care of it ourselves
    
    def cpu(self):
        super(TaylorBNConv2d, self).cpu()
        self.taylor.cpu()
        return self
    
    def cuda(self):
        super(TaylorBNConv2d, self).cuda()
        self.taylor.cuda()
        return self


class TaylorCNN(torch.nn.Module):
    
    def __init__(self, num_class, taylor):
        super(TaylorCNN, self).__init__()
        
        # prepare taylorizers for maxpool operations
        self.taylor0 = taylor
        self.taylor1 = self.taylor0.pool2d((2,2))
        self.taylor2 = self.taylor1.pool2d((2,2))
        self.taylor3 = self.taylor2.pool2d((2,2))
        #taylor4 = taylor3.pool2d((2,2))
        
        # feature extractor CNN
        self._feature = torch.nn.Sequential(
            # taylor conv
            TaylorBNConv2d( 2,16,self.taylor0), torch.nn.ReLU(),
            TaylorBNConv2d(16,32,self.taylor0), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d(32,32,self.taylor1), torch.nn.ReLU(),
            TaylorBNConv2d(32,32,self.taylor1), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d(32,64,self.taylor2), torch.nn.ReLU(),
            TaylorBNConv2d(64,64,self.taylor2), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d( 64,128,self.taylor3), torch.nn.ReLU(),
            TaylorBNConv2d(128,128,self.taylor3), torch.nn.ReLU()
        )
        self._classifier = torch.nn.Sequential(
            torch.nn.Linear(128,32), torch.nn.ReLU(),
            torch.nn.Linear(32,num_class)
        )

    def forward(self, x):
        net = self._feature(x)
        net = torch.nn.AvgPool2d(net.size()[2:])(net)
        return self._classifier(net.view(-1,128))
    
    def rot(self, phi):
        self.taylor0.rotPhi = phi
        self.taylor1.rotPhi = phi
        self.taylor2.rotPhi = phi
        self.taylor3.rotPhi = phi
    
    # I'm not sure why I need to implement cpu/cuda myself, train works somehow
    
    def cpu(self):
        super(TaylorCNN, self).cpu()
        for module in self._feature:
            module.cpu()
        for module in self._classifier:
            module.cpu()
        return self
    
    def cuda(self):
        super(TaylorCNN, self).cuda()
        for module in self._feature:
            module.cuda()
        for module in self._classifier:
            module.cuda()
        return self

# %%
def forward(blob,train=True):
    """
       Args: blob should have attributes, net, criterion, softmax, data, label
       Returns: a dictionary of predicted labels, softmax, loss, and accuracy
    """
    with torch.set_grad_enabled(train):
        # Prediction
        data = torch.as_tensor(blob.data).cuda()#[torch.as_tensor(d).cuda() for d in blob.data]
        data = data.permute(0,3,1,2)
        prediction = blob.net(data)
        # Training
        loss,acc=-1,-1
        if blob.label is not None:
            label = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()#[torch.as_tensor(l).cuda() for l in blob.label]
            #label = torch.as_tensor(blob.label).type(torch.FloatTensor).cuda()#[torch.as_tensor(l).cuda() for l in blob.label]
            label.requires_grad = False
            loss = blob.criterion(prediction,label)
        blob.loss = loss
        
        softmax    = blob.softmax(prediction).cpu().detach().numpy()
        prediction = torch.argmax(prediction,dim=-1)
        accuracy   = (prediction == label).sum().item() / float(prediction.nelement())
        # mse        = blob.mse(prediction,label).cpu().detach().numpy()
        # accuracy   = np.sqrt(mse.mean()).item()
        prediction = prediction.cpu().detach().numpy()
        
        return {'prediction' : prediction,
                'softmax'    : softmax,
                'loss'       : loss.cpu().detach().item(),
                'accuracy'   : accuracy}

def backward(blob):
    blob.optimizer.zero_grad()  # Reset gradients accumulation
    blob.loss.backward()
    blob.optimizer.step()

def save_state(blob):
    # Output file name
    filename = '%s-%d.ckpt' % (blob.prefix, blob.iteration)
    # Save parameters
    # 0+1) iteration counter + optimizer state => in case we want to "continue training" later
    # 2) network weight
    torch.save({
        'global_epoch': blob.epoch,
        'global_step': blob.iteration,
        'optimizer': blob.optimizer.state_dict(),
        'state_dict': blob.net.state_dict()
        }, filename)
    return filename

def restore_state(blob, iteration):
    # Open a file in read-binary mode
    weight_file = '%s-%d.ckpt' % (prefix.prefix, iteration)
    with open(weight_file, 'rb') as f:
        # torch interprets the file, then we can access using string keys
        checkpoint = torch.load(f)
        # load network weights
        blob.net.load_state_dict(checkpoint['state_dict'], strict=False)
        # if optimizer is provided, load the state of the optimizer
        if blob.optimizer is not None:
            blob.optimizer.load_state_dict(checkpoint['optimizer'])
        # load iteration count
        blob.epoch     = checkpoint['global_epoch']
        blob.iteration = checkpoint['global_step']

# weight_file = save_state(blob, '20190819-02-DeepTaylor-01-BatchNorm')
# print('Saved to', weight_file)


# # Recreate the network (i.e. initialize)
# blob.net=LeNet().cuda()
# # Get one batch of data to test
# blob.data, blob.label = next(iter(train_loader))
# # Run forward function
# res = forward(blob,True)
# # Report
# print('Accuracy:',res['accuracy'])



# # Restore the state
# restore_state(weight_file,blob)
# # Run the forward function
# res = forward(blob,True)
# # Report
# print('Accuracy',res['accuracy'])

# %%
class BLOB:
    pass
blob=BLOB()
blob.net       = TaylorCNN(3, taylor0).cuda() # construct CNN for 1 variable regression, use GPU
blob.criterion = torch.nn.CrossEntropyLoss() # use softmax loss to define an error
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.prefix    = '20191003-01-trackReco-01-timing'
blob.epoch     = 0.
blob.iteration = 0
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis
# Out:
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done

# %%
import time
from utils.utils import progress_bar, CSVData

blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)

# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=14.0
# Set the network to training mode
blob.net.train()

# Start training
while int(blob.epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(blob.epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data,blob.label = data[0:2]
        blob.net.rot(data[3])
        # here we would also need to rotate the truth information (i.e. any vector data in label)
        
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        blob.epoch += 1./len(train_loader)
        blob.iteration += 1
        
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%3 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%10 == 0:
            with torch.no_grad():
                blob.net.eval()
                test_data = next(iter(test_loader))
                blob.data,blob.label = test_data[0:2]
                res = forward(blob,False)
                blob.test_log.record(['iteration','epoch','accuracy','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['loss']])
                blob.test_log.write()
            blob.net.train()
        # even more rarely, save state
        if (i+1)%400 == 0:
            with torch.no_grad():
                blob.net.eval()
                save_state(blob)
            blob.net.train()
        if blob.epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'])
    #print(message)
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.test_log.close()
blob.train_log.close()
# Out:
# Epoch 0 Starting @ 2019-10-03 09:19:14
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 59 ... Epoch 1.00 ... Loss 1.007 ... Accuracy 0.579
# Epoch 1 Starting @ 2019-10-03 09:20:00
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 118 ... Epoch 2.00 ... Loss 1.071 ... Accuracy 0.421
# Epoch 2 Starting @ 2019-10-03 09:20:35
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 177 ... Epoch 3.00 ... Loss 1.054 ... Accuracy 0.474
# Epoch 3 Starting @ 2019-10-03 09:21:10
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 236 ... Epoch 4.00 ... Loss 1.050 ... Accuracy 0.526
# Epoch 4 Starting @ 2019-10-03 09:21:46
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 295 ... Epoch 5.00 ... Loss 1.011 ... Accuracy 0.500
# Epoch 5 Starting @ 2019-10-03 09:22:21
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 354 ... Epoch 6.00 ... Loss 0.934 ... Accuracy 0.526
# Epoch 6 Starting @ 2019-10-03 09:22:56
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 413 ... Epoch 7.00 ... Loss 0.983 ... Accuracy 0.500
# Epoch 7 Starting @ 2019-10-03 09:23:32
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 472 ... Epoch 8.00 ... Loss 0.883 ... Accuracy 0.632
# Epoch 8 Starting @ 2019-10-03 09:24:07
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 531 ... Epoch 9.00 ... Loss 0.861 ... Accuracy 0.553
# Epoch 9 Starting @ 2019-10-03 09:24:42
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 590 ... Epoch 10.00 ... Loss 0.910 ... Accuracy 0.553
# Epoch 10 Starting @ 2019-10-03 09:25:18
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 649 ... Epoch 11.00 ... Loss 0.723 ... Accuracy 0.658
# Epoch 11 Starting @ 2019-10-03 09:25:53
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 708 ... Epoch 12.00 ... Loss 0.665 ... Accuracy 0.684
# Epoch 12 Starting @ 2019-10-03 09:26:28
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 767 ... Epoch 13.00 ... Loss 0.751 ... Accuracy 0.579
# Epoch 13 Starting @ 2019-10-03 09:27:03
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 826 ... Epoch 14.00 ... Loss 0.590 ... Accuracy 0.711

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.accuracy, linewidth=2, label='Train accuracy', color='r', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.accuracy, marker='o', markersize=12, linestyle='', label='Test accuracy', color='red')

ax2.set_ylabel('Accuracy', fontsize=24, fontweight='bold',color='r')
ax2.tick_params('y',colors='r',labelsize=18)
ax2.set_ylim(0.,1.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %% [markdown]
# ## Now add energy reconstruction

# %%
from torch.utils.data import Dataset, DataLoader

class H5DatasetWithTrack(Dataset):

    def __init__(self, files, transform=None, flavour=None, limit_num_files=0, start_fraction=0., use_fraction=1.0):
        """                                                                                                                                             
        Args: data_dirs ... a list of data directories to find files (up to 10 files read from each dir)                                                
              transform ... a function applied to pre-process data                                                                                      
              flavour ..... a string that is required to be present in the filename                                                                     
              limit_num_files ... an integer limiting number of files to be taken per data directory                                                    
              start_fraction ... a floating point fraction (0.0=>1.0) to specify which entry to start reading (per file)                                
              use_fraction ..... a floating point fraction (0.0=>1.0) to specify how much fraction of a file to be read out (per file)                  
        """
        self._transform = transform
        self._files = []

        # Check input fractions makes sense                                                                                                             
        assert start_fraction >= 0. and start_fraction < 1.
        assert use_fraction > 0. and use_fraction <= 1.
        assert (start_fraction + use_fraction) <= 1.

        # Load files (up to 10) from each directory in data_dirs list                                                                                   
        # for d in data_dirs:
        #     file_list = [ os.path.join(d,f) for f in os.listdir(d) if flavour is None or flavour in f ]
        #     if limit_num_files: file_list = file_list[0:limit_num_files]
        #     self._files += file_list
        self._files = files

        self._file_handles = [None] * len(self._files)
        self._event_to_file_index  = []
        self._event_to_entry_index = []
        import h5py
        for file_index, file_name in enumerate(self._files):
            f = h5py.File(file_name,mode='r')
            data_size = f['event_data'].shape[0]
            start_entry = int(start_fraction * data_size)
            num_entries = int(use_fraction * data_size)
            self._event_to_file_index += [file_index] * num_entries
            self._event_to_entry_index += range(start_entry, start_entry+num_entries)
            f.close()

    def __len__(self):
        return len(self._event_to_file_index)

    def __getitem__(self,idx):
        file_index = self._event_to_file_index[idx]
        entry_index = self._event_to_entry_index[idx]
        if self._file_handles[file_index] is None:
            import h5py
            self._file_handles[file_index] = h5py.File(self._files[file_index],mode='r')
        fh = self._file_handles[file_index]
        label = fh['labels'][entry_index]
        #labelTranslation = [-1,0,1,-1,2] # make sure that labels 1,2,4 get values 0,1,2
        if label == 1: # electron
            label = 0
        elif label == 2: # muon
            label = 1
        elif label == 4: # pip
            label = 2
        else:
            print('Unknown label', label, 'for entry_index', entry_index, 'treating as label=0')
            label = 0
        
        # try:
        #     label = labelTranslation[label]
        # except IndexError:
        #     print('IndexError at entry', entry_index, 'label in file was', fh['labels'][entry_index], 'translations are', labelTranslation)
        #     raise
        
        keys = ['event_data','directions','energies','positions']
        out = {
            "label":      label,
            "idx":        idx
        }
        for key in iter(keys):
            out[key] = fh[key][entry_index]
        
        return out

def HKCollateWithTrack(batch):
    stack = {}
    for key in iter(batch[0].keys()):
        if key == "event_data" or key == "directions" or key == "energies" or key == "positions":
            stack[key] = np.stack([sample[key] for sample in batch])
        else:
            stack[key] = [sample[key] for sample in batch]
    
    stack["rndmRot"] = np.random.uniform(0., 2*np.pi)
    return stack
# e.g. positions will have shape (B,2,3) with B=batch-size, 2=(the two particles), 3=(vector coordinates)

# %%
# also add more data

#mcdir = '/home/lukasb/projects/rpp-tanaka-ab/lukasb/watchmal/20190808-uniisoflat'
mcdir = '/home/lukasb/scratch/20190808-uniisoflat'
wallmat = 'blacksheet'
pnames = ('e','mu','pip')
files = ['%s/1R%s-%s/wc-0-bch%d.h5' % (mcdir,pname,wallmat,bch+1) for bch in range(5) for pname in pnames]

train_ds = H5DatasetWithTrack(files,start_fraction=0.0,use_fraction=0.5);
test_ds  = H5DatasetWithTrack(files,start_fraction=0.5,use_fraction=0.1);

# for training
train_loader=DataLoader(train_ds,batch_size= 64,shuffle=True,num_workers=4,collate_fn=HKCollateWithTrack)
# for validation
test_loader =DataLoader( test_ds,batch_size=200,shuffle=True,num_workers=2,collate_fn=HKCollateWithTrack)

# %%
keys = ['event_data','directions','energies','positions']
for key in keys:
    print("%s.shape" % key, e[key].shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ce2c8c2e6328> in <module>
#       1 keys = ['event_data','directions','energies','positions']
#       2 for key in keys:
# ----> 3     print("%s.shape" % key, e[key].shape)
#
# NameError: name 'e' is not defined

# %%
def computeLoss(blob,prediction):
    """
        Args:
        - blob: should have label, energies, crossEntropy(), mse()
        - prediction: torch tensor with output from net
        
        Returns: loss for this prediction
    """
    
    Nclasses = 3
    predLabel = prediction[:,0:Nclasses]
    trueLabel = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()
    trueLabel.requires_grad = False
    labelLoss = blob.crossEntropy(predLabel, trueLabel)
    
    predSqrtEnergy = prediction[:,Nclasses:]
    trueEnergy = torch.as_tensor(blob.energies[:,0:1]).type(torch.FloatTensor).cuda()
    trueEnergy.requires_grad = False
    # only care about the first energy for now, but still maintain dimension
    #print("predEnergy", predEnergy)
    #print("trueEnergy", trueEnergy)
    energyLoss = blob.mse(predSqrtEnergy, torch.sqrt(trueEnergy))
    # energy error scales like dE ~ sqrt(E)
    # hence d[sqrt(E)] = dE/sqrt(E) ~ 1
    # so the loss should be more uniform across energies
    # which makes the learning faster
    
    #print("energyLoss", energyLoss)
    
    return labelLoss + energyLoss

def computeAccuracy(blob,prediction):
    Nclasses = 3
    predLabel = prediction[:,0:Nclasses]
    trueLabel = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()
    trueLabel.requires_grad = False
    
    softmax    = blob.softmax(predLabel).cpu().detach().numpy()
    whichLabel = torch.argmax(predLabel,dim=-1)
    accuracy   = (whichLabel == trueLabel).sum().item() / float(whichLabel.nelement())
    whichLabel = whichLabel.cpu().detach().numpy()
    
    predEnergy = torch.pow(prediction[:,Nclasses:],2)
    trueEnergy = torch.as_tensor(blob.energies[:,0:1]).type(torch.FloatTensor).cuda()
    trueEnergy.requires_grad = False
    # only care about the first energy for now
    energyResolution = blob.mse(predEnergy, trueEnergy) / (trueEnergy * trueEnergy)
    energyResolution = energyResolution.cpu().detach().numpy()
    energyResolution = np.sqrt(energyResolution.mean()).item()
    
    out = {
        "accuracy": accuracy,                 # double
        "energyResolution": energyResolution, # double
        "softmax": softmax,                   # np.array (batch,labels)
        "predicition": whichLabel             # np.array (batch)
    }
    return out

def forward(blob,train=True):
    """
       Args: blob should have attributes, net, criterion, softmax, data, label
       Returns: a dictionary of predicted labels, softmax, loss, and accuracy
    """
    with torch.set_grad_enabled(train):
        # Prediction
        data = torch.as_tensor(blob.data).cuda()#[torch.as_tensor(d).cuda() for d in blob.data]
        data = data.permute(0,3,1,2)
        prediction = blob.net(data)
        # prediction.shape = (batchSize,nClasses) 
        
        # Training
        loss,acc=-1,-1
        if blob.label is not None:
            loss = computeLoss(blob, prediction)
        blob.loss = loss
        #print(loss)
        
        out = computeAccuracy(blob, prediction)
        out['loss'] = loss.cpu().detach().item()
        
        return out

def backward(blob):
    blob.optimizer.zero_grad()  # Reset gradients accumulation
    blob.loss.backward()
    blob.optimizer.step()

def save_state(blob):
    # Output file name
    filename = '%s-%d.ckpt' % (blob.prefix, blob.iteration)
    # Save parameters
    # 0+1) iteration counter + optimizer state => in case we want to "continue training" later
    # 2) network weight
    torch.save({
        'global_epoch': blob.epoch,
        'global_step': blob.iteration,
        'optimizer': blob.optimizer.state_dict(),
        'state_dict': blob.net.state_dict()
        }, filename)
    return filename

def restore_state(blob, iteration):
    # Open a file in read-binary mode
    weight_file = '%s-%d.ckpt' % (prefix.prefix, iteration)
    with open(weight_file, 'rb') as f:
        # torch interprets the file, then we can access using string keys
        checkpoint = torch.load(f)
        # load network weights
        blob.net.load_state_dict(checkpoint['state_dict'], strict=False)
        # if optimizer is provided, load the state of the optimizer
        if blob.optimizer is not None:
            blob.optimizer.load_state_dict(checkpoint['optimizer'])
        # load iteration count
        blob.epoch     = checkpoint['global_epoch']
        blob.iteration = checkpoint['global_step']

# weight_file = save_state(blob, '20190819-02-DeepTaylor-01-BatchNorm')
# print('Saved to', weight_file)


# # Recreate the network (i.e. initialize)
# blob.net=LeNet().cuda()
# # Get one batch of data to test
# blob.data, blob.label = next(iter(train_loader))
# # Run forward function
# res = forward(blob,True)
# # Report
# print('Accuracy:',res['accuracy'])



# # Restore the state
# restore_state(weight_file,blob)
# # Run the forward function
# res = forward(blob,True)
# # Report
# print('Accuracy',res['accuracy'])

# %%
class BLOB:
    pass
blob=BLOB()
blob.net       = TaylorCNN(4, taylor0).cuda() # construct CNN for 3 labels + 1 energy, use GPU
blob.crossEntropy = torch.nn.CrossEntropyLoss() # use softmax loss to define an error
blob.mse          = torch.nn.MSELoss()
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.prefix    = '20191003-01-trackReco-02-classPlusEreco'
blob.epoch     = 0.
blob.iteration = 0
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis
blob.energies  = None # energies for training/analysis
# Out:
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done

# %%
import time
from utils.utils import progress_bar, CSVData

blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)

# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=5.0
# Set the network to training mode
blob.net.train()

# Start training
while int(blob.epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(blob.epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data  = data['event_data']
        blob.label = data['label']
        blob.energies = data['energies']
        blob.net.rot(data['rndmRot'])
        # here we would also need to rotate the truth information (i.e. any vector data in label)
        
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        blob.epoch += 1./len(train_loader)
        blob.iteration += 1
        
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%3 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%10 == 0:
            with torch.no_grad():
                blob.net.eval()
                test_data = next(iter(test_loader))
                blob.data  = test_data['event_data']
                blob.label = test_data['label']
                blob.energies = test_data['energies']
                blob.net.rot(test_data['rndmRot'])
                res = forward(blob,False)
                blob.test_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
                blob.test_log.write()
            blob.net.train()
        # even more rarely, save state
        if (i+1)%400 == 0:
            with torch.no_grad():
                blob.net.eval()
                save_state(blob)
            blob.net.train()
        if blob.epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
    #print(message)
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.test_log.close()
blob.train_log.close()
# Out:
# Epoch 1 Starting @ 2019-10-03 15:15:33
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 118 ... Epoch 2.00 ... Loss 44.573 ... Accuracy 0.447 ... Eres 1.056
# Epoch 2 Starting @ 2019-10-03 15:16:11
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 177 ... Epoch 3.00 ... Loss 26.534 ... Accuracy 0.474 ... Eres 0.828
# Epoch 3 Starting @ 2019-10-03 15:16:48
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 236 ... Epoch 4.00 ... Loss 36.788 ... Accuracy 0.421 ... Eres 3.888
# Epoch 4 Starting @ 2019-10-03 15:17:25
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 295 ... Epoch 5.00 ... Loss 27.541 ... Accuracy 0.368 ... Eres 0.636

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.accuracy, linewidth=2, label='Train accuracy', color='r', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.accuracy, marker='o', markersize=12, linestyle='', label='Test accuracy', color='red')

ax2.set_ylabel('Accuracy', fontsize=24, fontweight='bold',color='r')
ax2.tick_params('y',colors='r',labelsize=18)
ax2.set_ylim(0.,1.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.energyResolution, linewidth=2, label='Train Eres', color='g', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.energyResolution, marker='o', markersize=12, linestyle='', label='Test Eres', color='green')

ax2.set_ylabel('Energy resolution', fontsize=24, fontweight='bold',color='g')
ax2.tick_params('y',colors='g',labelsize=18)
ax2.set_ylim(0.,3.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %% [markdown]
# ## Reduce weight of energy loss function

# %%
def computeLoss(blob,prediction):
    """
        Args:
        - blob: should have label, energies, crossEntropy(), mse(), energyLossFactor
        - prediction: torch tensor with output from net
        
        Returns: loss for this prediction
    """
    
    Nclasses = 3
    predLabel = prediction[:,0:Nclasses]
    trueLabel = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()
    trueLabel.requires_grad = False
    labelLoss = blob.crossEntropy(predLabel, trueLabel)
    
    predSqrtEnergy = prediction[:,Nclasses:]
    trueEnergy = torch.as_tensor(blob.energies[:,0:1]).type(torch.FloatTensor).cuda()
    trueEnergy.requires_grad = False
    # only care about the first energy for now, but still maintain dimension
    #print("predEnergy", predEnergy)
    #print("trueEnergy", trueEnergy)
    energyLoss = blob.mse(predSqrtEnergy, torch.sqrt(trueEnergy))
    # energy error scales like dE ~ sqrt(E)
    # hence d[sqrt(E)] = dE/sqrt(E) ~ 1
    # so the loss should be more uniform across energies
    # which makes the learning faster
    
    #print("energyLoss", energyLoss)
    
    return labelLoss + blob.energyLossFactor * energyLoss

def computeAccuracy(blob,prediction):
    Nclasses = 3
    predLabel = prediction[:,0:Nclasses]
    trueLabel = torch.as_tensor(blob.label).type(torch.LongTensor).cuda()
    trueLabel.requires_grad = False
    
    softmax    = blob.softmax(predLabel).cpu().detach().numpy()
    whichLabel = torch.argmax(predLabel,dim=-1)
    accuracy   = (whichLabel == trueLabel).sum().item() / float(whichLabel.nelement())
    whichLabel = whichLabel.cpu().detach().numpy()
    
    predEnergy = torch.pow(prediction[:,Nclasses:],2)
    trueEnergy = torch.as_tensor(blob.energies[:,0:1]).type(torch.FloatTensor).cuda()
    trueEnergy.requires_grad = False
    # only care about the first energy for now
    energyResolution = blob.mse(predEnergy, trueEnergy) / (trueEnergy * trueEnergy)
    energyResolution = energyResolution.cpu().detach().numpy()
    energyResolution = np.sqrt(energyResolution.mean()).item()
    
    out = {
        "accuracy": accuracy,                 # double
        "energyResolution": energyResolution, # double
        "softmax": softmax,                   # np.array (batch,labels)
        "predicition": whichLabel             # np.array (batch)
    }
    return out

def forward(blob,train=True):
    """
       Args: blob should have attributes, net, criterion, softmax, data, label
       Returns: a dictionary of predicted labels, softmax, loss, and accuracy
    """
    with torch.set_grad_enabled(train):
        # Prediction
        data = torch.as_tensor(blob.data).cuda()#[torch.as_tensor(d).cuda() for d in blob.data]
        data = data.permute(0,3,1,2)
        prediction = blob.net(data)
        # prediction.shape = (batchSize,nClasses) 
        
        # Training
        loss,acc=-1,-1
        if blob.label is not None:
            loss = computeLoss(blob, prediction)
        blob.loss = loss
        #print(loss)
        
        out = computeAccuracy(blob, prediction)
        out['loss'] = loss.cpu().detach().item()
        
        return out

def backward(blob):
    blob.optimizer.zero_grad()  # Reset gradients accumulation
    blob.loss.backward()
    blob.optimizer.step()

def save_state(blob):
    # Output file name
    filename = '%s-%d.ckpt' % (blob.prefix, blob.iteration)
    # Save parameters
    # 0+1) iteration counter + optimizer state => in case we want to "continue training" later
    # 2) network weight
    torch.save({
        'global_epoch': blob.epoch,
        'global_step': blob.iteration,
        'optimizer': blob.optimizer.state_dict(),
        'state_dict': blob.net.state_dict()
        }, filename)
    return filename

def restore_state(blob, iteration):
    # Open a file in read-binary mode
    weight_file = '%s-%d.ckpt' % (prefix.prefix, iteration)
    with open(weight_file, 'rb') as f:
        # torch interprets the file, then we can access using string keys
        checkpoint = torch.load(f)
        # load network weights
        blob.net.load_state_dict(checkpoint['state_dict'], strict=False)
        # if optimizer is provided, load the state of the optimizer
        if blob.optimizer is not None:
            blob.optimizer.load_state_dict(checkpoint['optimizer'])
        # load iteration count
        blob.epoch     = checkpoint['global_epoch']
        blob.iteration = checkpoint['global_step']

# weight_file = save_state(blob, '20190819-02-DeepTaylor-01-BatchNorm')
# print('Saved to', weight_file)


# # Recreate the network (i.e. initialize)
# blob.net=LeNet().cuda()
# # Get one batch of data to test
# blob.data, blob.label = next(iter(train_loader))
# # Run forward function
# res = forward(blob,True)
# # Report
# print('Accuracy:',res['accuracy'])



# # Restore the state
# restore_state(weight_file,blob)
# # Run the forward function
# res = forward(blob,True)
# # Report
# print('Accuracy',res['accuracy'])

# %%
class BLOB:
    pass
blob=BLOB()
blob.net       = TaylorCNN(4, taylor0).cuda() # construct CNN for 3 labels + 1 energy, use GPU
blob.crossEntropy = torch.nn.CrossEntropyLoss() # use softmax loss to define an error
blob.mse          = torch.nn.MSELoss()
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.prefix    = '20191003-01-trackReco-02-classPlusEreco'
blob.epoch     = 0.
blob.iteration = 0
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis
blob.energies  = None # energies for training/analysis
blob.energyLossFactor = 0.01 # typical energy loss and classification loss should be of same order
# Out:
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done

# %%
import time
from utils.utils import progress_bar, CSVData

blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)

# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=5.0
# Set the network to training mode
blob.net.train()

# Start training
while int(blob.epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(blob.epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data  = data['event_data']
        blob.label = data['label']
        blob.energies = data['energies']
        blob.net.rot(data['rndmRot'])
        # here we would also need to rotate the truth information (i.e. any vector data in label)
        
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        blob.epoch += 1./len(train_loader)
        blob.iteration += 1
        
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%3 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%10 == 0:
            with torch.no_grad():
                blob.net.eval()
                test_data = next(iter(test_loader))
                blob.data  = test_data['event_data']
                blob.label = test_data['label']
                blob.energies = test_data['energies']
                blob.net.rot(test_data['rndmRot'])
                res = forward(blob,False)
                blob.test_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
                blob.test_log.write()
            blob.net.train()
        # even more rarely, save state
        if (i+1)%400 == 0:
            with torch.no_grad():
                blob.net.eval()
                save_state(blob)
            blob.net.train()
        if blob.epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
    #print(message)
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.test_log.close()
blob.train_log.close()
# Out:
# Epoch 0 Starting @ 2019-10-03 15:21:26
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 59 ... Epoch 1.00 ... Loss 1.403 ... Accuracy 0.368 ... Eres 0.757
# Epoch 1 Starting @ 2019-10-03 15:22:05
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 118 ... Epoch 2.00 ... Loss 1.208 ... Accuracy 0.500 ... Eres 0.653
# Epoch 2 Starting @ 2019-10-03 15:22:42
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 177 ... Epoch 3.00 ... Loss 1.392 ... Accuracy 0.447 ... Eres 8.345
# Epoch 3 Starting @ 2019-10-03 15:23:19
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 236 ... Epoch 4.00 ... Loss 1.446 ... Accuracy 0.368 ... Eres 6.769
# Epoch 4 Starting @ 2019-10-03 15:23:56
#         <progress
#             value='59'
#             max='59',
#             style='width: 30%'
#         >
#             59
#         </progress> 100% ... Iteration 295 ... Epoch 5.00 ... Loss 1.342 ... Accuracy 0.474 ... Eres 0.575

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.accuracy, linewidth=2, label='Train accuracy', color='r', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.accuracy, marker='o', markersize=12, linestyle='', label='Test accuracy', color='red')

ax2.set_ylabel('Accuracy', fontsize=24, fontweight='bold',color='r')
ax2.tick_params('y',colors='r',labelsize=18)
ax2.set_ylim(0.,1.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.energyResolution, linewidth=2, label='Train Eres', color='g', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.energyResolution, marker='o', markersize=12, linestyle='', label='Test Eres', color='green')

ax2.set_ylabel('Energy resolution', fontsize=24, fontweight='bold',color='g')
ax2.tick_params('y',colors='g',labelsize=18)
ax2.set_ylim(0.,3.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %% [markdown]
# ## Separate MLP for classification and regression (and more data)

# %%
class GeomBNConv2d(torch.nn.Module):
    def __init__(self,Cin,Cout,pad):
        super(GeomBNConv2d, self).__init__()
        self.Cin = Cin
        self.Cout = Cout
        self.pad = pad
        self.batchNorm2d = torch.nn.BatchNorm2d(Cin)
        self.conv2d = torch.nn.Conv2d(Cin,Cout,2*self.pad+1)
 
    def forward(self, x):
        x = self.batchNorm2d(x)
        inputsPad = geometricPad(x, self.pad); # (B,C,W,H)
        return self.conv2d(inputsPad)

class TaylorBNConv2d(torch.nn.Module):
    def __init__(self,Cin,Cout,taylor):
        super(TaylorBNConv2d, self).__init__()
        self.Cin = Cin
        self.Cout = Cout
        self.taylor = taylor
        self.batchNorm2d = torch.nn.BatchNorm2d(Cin*taylor.Ntaylor)
        self.conv2d = torch.nn.Conv2d(Cin*taylor.Ntaylor,Cout,1)
 
    def forward(self, x):
        x = self.taylor(x)
        x = self.batchNorm2d(x)
        x = self.conv2d(x)
        return x
    
    # the default implementation of cpu() and cuda() only passes this along to nn.Module instances
    # since self.AA is a tensor, we need to take care of it ourselves
    
    def cpu(self):
        super(TaylorBNConv2d, self).cpu()
        self.taylor.cpu()
        return self
    
    def cuda(self):
        super(TaylorBNConv2d, self).cuda()
        self.taylor.cuda()
        return self


class TaylorClaRegCNN(torch.nn.Module):
    
    def __init__(self, num_class, num_regress, taylor):
        super(TaylorClaRegCNN, self).__init__()
        
        # prepare taylorizers for maxpool operations
        self.taylor0 = taylor
        self.taylor1 = self.taylor0.pool2d((2,2))
        self.taylor2 = self.taylor1.pool2d((2,2))
        self.taylor3 = self.taylor2.pool2d((2,2))
        #taylor4 = taylor3.pool2d((2,2))
        
        # feature extractor CNN
        self._feature = torch.nn.Sequential(
            # taylor conv
            TaylorBNConv2d( 2,16,self.taylor0), torch.nn.ReLU(),
            TaylorBNConv2d(16,32,self.taylor0), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d(32,32,self.taylor1), torch.nn.ReLU(),
            TaylorBNConv2d(32,32,self.taylor1), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d(32,64,self.taylor2), torch.nn.ReLU(),
            TaylorBNConv2d(64,64,self.taylor2), torch.nn.ReLU(),
            
            torch.nn.MaxPool2d(2,2),
            TaylorBNConv2d( 64,128,self.taylor3), torch.nn.ReLU(),
            TaylorBNConv2d(128,128,self.taylor3), torch.nn.ReLU()
        )
        self._classifier = torch.nn.Sequential(
            torch.nn.Linear(128,32), torch.nn.ReLU(),
            torch.nn.Linear(32,num_class)
        )
        self._regressor = torch.nn.Sequential(
            torch.nn.Linear(128,32), torch.nn.ReLU(),
            torch.nn.Linear(32,num_regress)
        )

    def forward(self, x):
        net = self._feature(x)
        net = torch.nn.AvgPool2d(net.size()[2:])(net)
        return torch.cat([
            self._classifier(net.view(-1,128)),
            self._regressor(net.view(-1,128))
        ], dim=1)
    
    def rot(self, phi):
        self.taylor0.rotPhi = phi
        self.taylor1.rotPhi = phi
        self.taylor2.rotPhi = phi
        self.taylor3.rotPhi = phi
    
    # I'm not sure why I need to implement cpu/cuda myself, train works somehow
    
    def cpu(self):
        super(TaylorClaRegCNN, self).cpu()
        for module in self._feature:
            module.cpu()
        for module in self._classifier:
            module.cpu()
        for module in self._regressor:
            module.cpu()
        return self
    
    def cuda(self):
        super(TaylorClaRegCNN, self).cuda()
        for module in self._feature:
            module.cuda()
        for module in self._classifier:
            module.cuda()
        for module in self._regressor:
            module.cuda()
        return self

# %%
# also add more data

#mcdir = '/home/lukasb/projects/rpp-tanaka-ab/lukasb/watchmal/20190808-uniisoflat'
mcdir = '/home/lukasb/scratch/20190808-uniisoflat'
wallmat = 'blacksheet'
pnames = ('e','mu','pip')
files = ['%s/1R%s-%s/wc-0-bch%d.h5' % (mcdir,pname,wallmat,bch+1) for bch in range(20) for pname in pnames]

train_ds = H5DatasetWithTrack(files,start_fraction=0.0,use_fraction=0.9);
test_ds  = H5DatasetWithTrack(files,start_fraction=0.9,use_fraction=0.1);

# for training
train_loader=DataLoader(train_ds,batch_size= 64,shuffle=True,num_workers=4,collate_fn=HKCollateWithTrack)
# for validation
test_loader =DataLoader( test_ds,batch_size=200,shuffle=True,num_workers=2,collate_fn=HKCollateWithTrack)

# %%
class BLOB:
    pass
blob=BLOB()
blob.net       = TaylorClaRegCNN(3, 1, taylor0).cuda() # construct CNN for 3 labels + 1 energy, use GPU
blob.crossEntropy = torch.nn.CrossEntropyLoss() # use softmax loss to define an error
blob.mse          = torch.nn.MSELoss()
blob.optimizer = torch.optim.Adam(blob.net.parameters()) # use Adam optimizer algorithm
blob.softmax   = torch.nn.Softmax(dim=1) # not for training, but softmax score for each class
blob.prefix    = '20191003-01-trackReco-03-TaylorClaReg'
blob.epoch     = 0.
blob.iteration = 0
blob.data      = None # data for training/analysis
blob.label     = None # label for training/analysis
blob.energies  = None # energies for training/analysis
blob.energyLossFactor = 0.001 # typical energy loss and classification loss should be of same order
# Out:
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done
# starting inversion... (may take a few seconds)
# done

# %%
import time
from utils.utils import progress_bar, CSVData

blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)

# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=5.0
# Set the network to training mode
blob.net.train()

# Start training
while int(blob.epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(blob.epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data  = data['event_data']
        blob.label = data['label']
        blob.energies = data['energies']
        blob.net.rot(data['rndmRot'])
        # here we would also need to rotate the truth information (i.e. any vector data in label)
        
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        blob.epoch += 1./len(train_loader)
        blob.iteration += 1
        
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%3 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%10 == 0:
            with torch.no_grad():
                blob.net.eval()
                test_data = next(iter(test_loader))
                blob.data  = test_data['event_data']
                blob.label = test_data['label']
                blob.energies = test_data['energies']
                blob.net.rot(test_data['rndmRot'])
                res = forward(blob,False)
                blob.test_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
                blob.test_log.write()
            blob.net.train()
        # even more rarely, save state
        if (i+1)%400 == 0:
            with torch.no_grad():
                blob.net.eval()
                save_state(blob)
            blob.net.train()
        if blob.epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
    #print(message)
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.test_log.close()
blob.train_log.close()
# Out:
# Epoch 0 Starting @ 2019-10-03 15:33:49
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 422 ... Epoch 1.00 ... Loss 0.981 ... Accuracy 0.500 ... Eres 0.849
# Epoch 1 Starting @ 2019-10-03 15:38:24
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 844 ... Epoch 2.00 ... Loss 0.605 ... Accuracy 0.768 ... Eres 1.758
# Epoch 2 Starting @ 2019-10-03 15:42:58
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 1266 ... Epoch 3.00 ... Loss 0.716 ... Accuracy 0.732 ... Eres 5.139
# Epoch 3 Starting @ 2019-10-03 15:47:33
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 1688 ... Epoch 4.00 ... Loss 0.792 ... Accuracy 0.679 ... Eres 1.260
# Epoch 4 Starting @ 2019-10-03 15:52:08
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 2110 ... Epoch 5.00 ... Loss 0.600 ... Accuracy 0.750 ... Eres 2.009

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.accuracy, linewidth=2, label='Train accuracy', color='r', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.accuracy, marker='o', markersize=12, linestyle='', label='Test accuracy', color='red')

ax2.set_ylabel('Accuracy', fontsize=24, fontweight='bold',color='r')
ax2.tick_params('y',colors='r',labelsize=18)
ax2.set_ylim(0.,1.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.energyResolution, linewidth=2, label='Train Eres', color='g', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.energyResolution, marker='o', markersize=12, linestyle='', label='Test Eres', color='green')

ax2.set_ylabel('Energy resolution', fontsize=24, fontweight='bold',color='g')
ax2.tick_params('y',colors='g',labelsize=18)
ax2.set_ylim(0.,3.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %%
# increase the energy loss factor
blob.energyLossFactor = 0.01

# %%
import time
from utils.utils import progress_bar, CSVData

blob.train_log, blob.test_log = CSVData('%s-log_train.csv' % blob.prefix), CSVData('%s-log_test.csv' % blob.prefix)

# Define train period. "epoch" = N image consumption where N is the total number of train samples.
TRAIN_EPOCH=40.0
# Set the network to training mode
blob.net.train()

# Start training
while int(blob.epoch+0.5) < TRAIN_EPOCH:
    print('Epoch',int(blob.epoch+0.5),'Starting @',time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))
    # Create a progress bar for this epoch
    progress = display(progress_bar(0,len(train_loader)),display_id=True)
    # Loop over data samples and into the network forward function
    for i,data in enumerate(train_loader):
        # Data and label
        blob.data  = data['event_data']
        blob.label = data['label']
        blob.energies = data['energies']
        blob.net.rot(data['rndmRot'])
        # here we would also need to rotate the truth information (i.e. any vector data in label)
        
        # Call forward: make a prediction & measure the average error
        res = forward(blob,True)
        # Call backward: backpropagate error and update weights
        backward(blob)
        # Epoch update
        blob.epoch += 1./len(train_loader)
        blob.iteration += 1
        
        #
        # Log/Report
        #
        # Record the current performance on train set
        blob.train_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
        blob.train_log.write()
        # once in a while, report
        if i==0 or (i+1)%3 == 0:
            message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
            progress.update(progress_bar((i+1),len(train_loader),message))
        # more rarely, run validation
        if (i+1)%10 == 0:
            with torch.no_grad():
                blob.net.eval()
                test_data = next(iter(test_loader))
                blob.data  = test_data['event_data']
                blob.label = test_data['label']
                blob.energies = test_data['energies']
                blob.net.rot(test_data['rndmRot'])
                res = forward(blob,False)
                blob.test_log.record(['iteration','epoch','accuracy','energyResolution','loss'],[blob.iteration,blob.epoch,res['accuracy'],res['energyResolution'],res['loss']])
                blob.test_log.write()
            blob.net.train()
        # even more rarely, save state
        if (i+1)%400 == 0:
            with torch.no_grad():
                blob.net.eval()
                save_state(blob)
            blob.net.train()
        if blob.epoch >= TRAIN_EPOCH:
            break
    message = '... Iteration %d ... Epoch %1.2f ... Loss %1.3f ... Accuracy %1.3f ... Eres %1.3f' % (blob.iteration,blob.epoch,res['loss'],res['accuracy'],res['energyResolution'])
    #print(message)
    progress.update(progress_bar((i+1),len(train_loader),message))

blob.test_log.close()
blob.train_log.close()
# Out:
# Epoch 5 Starting @ 2019-10-03 16:03:13
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 2532 ... Epoch 6.00 ... Loss 0.711 ... Accuracy 0.786 ... Eres 0.479
# Epoch 6 Starting @ 2019-10-03 16:07:51
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 2954 ... Epoch 7.00 ... Loss 0.567 ... Accuracy 0.786 ... Eres 2.314
# Epoch 7 Starting @ 2019-10-03 16:12:26
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 3376 ... Epoch 8.00 ... Loss 0.894 ... Accuracy 0.679 ... Eres 5.670
# Epoch 8 Starting @ 2019-10-03 16:17:01
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 3798 ... Epoch 9.00 ... Loss 0.631 ... Accuracy 0.786 ... Eres 0.409
# Epoch 9 Starting @ 2019-10-03 16:21:36
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 4220 ... Epoch 10.00 ... Loss 0.530 ... Accuracy 0.804 ... Eres 0.432
# Epoch 10 Starting @ 2019-10-03 16:26:11
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 4642 ... Epoch 11.00 ... Loss 0.603 ... Accuracy 0.786 ... Eres 0.614
# Epoch 11 Starting @ 2019-10-03 16:30:46
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 5064 ... Epoch 12.00 ... Loss 0.830 ... Accuracy 0.625 ... Eres 0.773
# Epoch 12 Starting @ 2019-10-03 16:35:21
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 5486 ... Epoch 13.00 ... Loss 0.688 ... Accuracy 0.768 ... Eres 1.554
# Epoch 13 Starting @ 2019-10-03 16:39:55
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 5908 ... Epoch 14.00 ... Loss 0.659 ... Accuracy 0.750 ... Eres 4.273
# Epoch 14 Starting @ 2019-10-03 16:44:30
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 6330 ... Epoch 15.00 ... Loss 0.672 ... Accuracy 0.714 ... Eres 0.347
# Epoch 15 Starting @ 2019-10-03 16:49:05
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 6752 ... Epoch 16.00 ... Loss 0.593 ... Accuracy 0.768 ... Eres 1.760
# Epoch 16 Starting @ 2019-10-03 16:53:40
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 7174 ... Epoch 17.00 ... Loss 0.567 ... Accuracy 0.839 ... Eres 10.841
# Epoch 17 Starting @ 2019-10-03 16:59:12
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 7596 ... Epoch 18.00 ... Loss 0.308 ... Accuracy 0.911 ... Eres 0.284
# Epoch 18 Starting @ 2019-10-03 17:03:47
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 8018 ... Epoch 19.00 ... Loss 0.749 ... Accuracy 0.732 ... Eres 2.247
# Epoch 19 Starting @ 2019-10-03 17:08:22
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 8440 ... Epoch 20.00 ... Loss 0.640 ... Accuracy 0.821 ... Eres 1.029
# Epoch 20 Starting @ 2019-10-03 17:12:57
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 8862 ... Epoch 21.00 ... Loss 0.490 ... Accuracy 0.857 ... Eres 1.253
# Epoch 21 Starting @ 2019-10-03 17:17:31
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 9284 ... Epoch 22.00 ... Loss 0.554 ... Accuracy 0.821 ... Eres 1.096
# Epoch 22 Starting @ 2019-10-03 17:22:06
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 9706 ... Epoch 23.00 ... Loss 0.560 ... Accuracy 0.839 ... Eres 0.474
# Epoch 23 Starting @ 2019-10-03 17:26:41
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 10128 ... Epoch 24.00 ... Loss 0.492 ... Accuracy 0.839 ... Eres 1.286
# Epoch 24 Starting @ 2019-10-03 17:31:15
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 10550 ... Epoch 25.00 ... Loss 0.611 ... Accuracy 0.750 ... Eres 0.496
# Epoch 25 Starting @ 2019-10-03 17:35:50
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 10972 ... Epoch 26.00 ... Loss 0.371 ... Accuracy 0.893 ... Eres 0.400
# Epoch 26 Starting @ 2019-10-03 17:40:25
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 11394 ... Epoch 27.00 ... Loss 0.440 ... Accuracy 0.786 ... Eres 3.821
# Epoch 27 Starting @ 2019-10-03 17:45:01
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 11816 ... Epoch 28.00 ... Loss 0.703 ... Accuracy 0.768 ... Eres 1.277
# Epoch 28 Starting @ 2019-10-03 17:49:38
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 12238 ... Epoch 29.00 ... Loss 0.639 ... Accuracy 0.714 ... Eres 0.466
# Epoch 29 Starting @ 2019-10-03 17:54:14
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 12660 ... Epoch 30.00 ... Loss 0.582 ... Accuracy 0.804 ... Eres 1.293
# Epoch 30 Starting @ 2019-10-03 17:58:49
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 13082 ... Epoch 31.00 ... Loss 0.424 ... Accuracy 0.875 ... Eres 0.481
# Epoch 31 Starting @ 2019-10-03 18:03:24
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 13504 ... Epoch 32.00 ... Loss 0.527 ... Accuracy 0.821 ... Eres 0.663
# Epoch 32 Starting @ 2019-10-03 18:08:00
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 13926 ... Epoch 33.00 ... Loss 0.577 ... Accuracy 0.821 ... Eres 0.441
# Epoch 33 Starting @ 2019-10-03 18:12:38
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 14348 ... Epoch 34.00 ... Loss 0.519 ... Accuracy 0.804 ... Eres 1.483
# Epoch 34 Starting @ 2019-10-03 18:17:16
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 14770 ... Epoch 35.00 ... Loss 0.568 ... Accuracy 0.857 ... Eres 0.680
# Epoch 35 Starting @ 2019-10-03 18:21:54
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 15192 ... Epoch 36.00 ... Loss 0.663 ... Accuracy 0.786 ... Eres 0.945
# Epoch 36 Starting @ 2019-10-03 18:26:31
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 15614 ... Epoch 37.00 ... Loss 0.387 ... Accuracy 0.893 ... Eres 0.597
# Epoch 37 Starting @ 2019-10-03 18:31:09
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 16036 ... Epoch 38.00 ... Loss 0.616 ... Accuracy 0.786 ... Eres 0.551
# Epoch 38 Starting @ 2019-10-03 18:35:47
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 16458 ... Epoch 39.00 ... Loss 0.588 ... Accuracy 0.714 ... Eres 1.191
# Epoch 39 Starting @ 2019-10-03 18:40:24
#         <progress
#             value='422'
#             max='422',
#             style='width: 30%'
#         >
#             422
#         </progress> 100% ... Iteration 16880 ... Epoch 40.00 ... Loss 0.473 ... Accuracy 0.857 ... Eres 4.340

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.accuracy, linewidth=2, label='Train accuracy', color='r', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.accuracy, marker='o', markersize=12, linestyle='', label='Test accuracy', color='red')

ax2.set_ylabel('Accuracy', fontsize=24, fontweight='bold',color='r')
ax2.tick_params('y',colors='r',labelsize=18)
ax2.set_ylim(0.,1.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

train_log = pd.read_csv(blob.train_log.name)
test_log  = pd.read_csv(blob.test_log.name)

fig, ax1 = plt.subplots(figsize=(12,8),facecolor='w')
line11 = ax1.plot(train_log.epoch, train_log.loss, linewidth=2, label='Train loss', color='b', alpha=0.3)
line12 = ax1.plot(test_log.epoch, test_log.loss, marker='o', markersize=12, linestyle='', label='Test loss', color='blue')
ax1.set_xlabel('Epoch',fontweight='bold',fontsize=24,color='black')
ax1.tick_params('x',colors='black',labelsize=18)
ax1.set_ylabel('Loss', fontsize=24, fontweight='bold',color='b')
ax1.tick_params('y',colors='b',labelsize=18)

ax2 = ax1.twinx()
line21 = ax2.plot(train_log.epoch, train_log.energyResolution, linewidth=2, label='Train Eres', color='g', alpha=0.3)
line22 = ax2.plot(test_log.epoch, test_log.energyResolution, marker='o', markersize=12, linestyle='', label='Test Eres', color='green')

ax2.set_ylabel('Energy resolution', fontsize=24, fontweight='bold',color='g')
ax2.tick_params('y',colors='g',labelsize=18)
ax2.set_ylim(0.,3.0)

# added these four lines
lines  = line11 + line12 + line21 + line22
labels = [l.get_label() for l in lines]
leg    = ax1.legend(lines, labels, fontsize=16, loc=5)
leg_frame = leg.get_frame()
leg_frame.set_facecolor('white')

plt.grid()
plt.show()
